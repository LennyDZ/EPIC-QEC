# %% [markdown]
# # Quick Start Guide
#
# EPIC-QEC is designed to facilitate the creation and benchmarking of Clifford computation using QEC solutions. It is divided into two subpackages: `core` and `modules`. The core contains the definitions of the abstractions as well as the compilation logic. The modules contain the implementations of the QEC solutions. To test a new QEC idea (code, surgery process, stabilizer schedule, etc.), one only has to focus on implementing the corresponding module, and then combine it with existing modules to test it in a full-stack, circuit-level noise experiment. Because the interfaces are well defined, it is easy to compare the performance of any new module with existing ones.
#
# In this guide, we show how to use EPIC-QEC to design a logical CNOT on rotated surface codes using lattice surgery.
#
# The first step is to define the stabilizer codes that are used. In general, EPIC-QEC supports any stabilizer code, and they are stored and processed as Tanner graphs. One can create any code given its symplectic parity-check matrix as well as a description of the logical operators. Here we use an existing macro to build `RotatedSurfaceCode` for a given distance. The system coordinates describe the positions of the patches; here they are required because lattice surgery relies on well-defined topology, but in general they are not required and may be used only for visualization purposes.

# %%
from epic import RotatedSurfaceCode

# Define stabilizer codes
code1 = RotatedSurfaceCode.from_distance(distance=3, system_coordinate=(0, 0), code_name="rsc1")
code2 = RotatedSurfaceCode.from_distance(distance=3, system_coordinate=(0, 1), code_name="rsc2")
code3 = RotatedSurfaceCode.from_distance(distance=3, system_coordinate=(1, 0), code_name="rsc3")

# %% [markdown]
# The next step is to write the program that we want to execute. In this context, a program is a list of instructions that we call QEC gadgets, executed sequentially. A `QECGadget` represents either a logical operation applied to some codes and/or logical qubits, typically Clifford gates or Pauli-product measurements, or an operation related to memory management, such as assigning physical qubits to code structures. As a reminder, a logical CNOT in lattice surgery is, as described in the figure below, a succession of ZZ and XX product measurements.
#
# Assuming there exists a module `RSCSurgery` that defines a Pauli-product measurement sequence (merge -> extract syndrome -> split -> extract syndrome), we can write our CNOT program as follows:

# %%
from epic import (
    AllocCode,
    FreeCode,
    InitCode,
    PauliChar,
    PauliEigenState,
    PauliString,
    RSCSurgery,
    ReadoutCode,
    RotatedSurfaceCode,
)
from epic.core.data_structure.quantum_program import ProgramQubit, QProgOperation, QuantumProgram
from epic.core.visualization.quantum_program_vis import draw_quantum_program

program_old = [
    AllocCode(target_code=code1, code_varname="ancilla_patch", logical_qubits_varnames=["ancilla"]),
    AllocCode(target_code=code2, code_varname="control_patch", logical_qubits_varnames=["control"]),
    AllocCode(target_code=code3, code_varname="target_patch", logical_qubits_varnames=["target"]),
    InitCode(targets=["ancilla_patch"], initial_state=PauliEigenState.Z_plus, tag="init_ancilla"),
    InitCode(targets=["control_patch"], initial_state=PauliEigenState.Z_plus, tag="init_control"),
    InitCode(targets=["target_patch"], initial_state=PauliEigenState.Z_plus, tag="init_target"),
    RSCSurgery(
        targets=["control", "ancilla"],
        product_to_measure=PauliString(string=(PauliChar.Z, PauliChar.Z)),
        tag="MZZ_ac",
    ),
    RSCSurgery(
        targets=["ancilla", "target"],
        product_to_measure=PauliString(string=(PauliChar.X, PauliChar.X)),
        tag="MXX_ct",
    ),
    ReadoutCode(targets=["control_patch"], tag="LZ_control"),
    ReadoutCode(targets=["ancilla_patch"], tag="LZ_ancilla"),
    ReadoutCode(targets=["target_patch"], tag="LZ_target"),
    FreeCode(code_varname="target_patch"),
    FreeCode(code_varname="control_patch"),
    FreeCode(code_varname="ancilla_patch"),
]

program = QuantumProgram(name="RSC_Surgery_Example")

aq = program.add_qubit(AllocCode(target_code=code1, code_varname="ancilla_patch", logical_qubits_varnames=["ancilla"]))
cq = program.add_qubit(AllocCode(target_code=code2, code_varname="control_patch", logical_qubits_varnames=["control"]))
tq = program.add_qubit(AllocCode(target_code=code3, code_varname="target_patch", logical_qubits_varnames=["target"]))

program.add_operation(QProgOperation(name="init_1", length=1, targets=[aq], implementation=InitCode(targets=["ancilla_patch"], initial_state=PauliEigenState.Z_plus, tag="init_ancilla")))
program.add_operation(QProgOperation(name="init_2", length=1, targets=[cq], implementation=InitCode(targets=["control_patch"], initial_state=PauliEigenState.Z_plus, tag="init_control")))
program.add_operation(QProgOperation(name="init_3", length=1, targets=[tq], implementation=InitCode(targets=["target_patch"], initial_state=PauliEigenState.Z_plus, tag="init_target")))

program.add_operation(QProgOperation(name="MZZ_ac", length=1, targets=[cq, aq], implementation=RSCSurgery(targets=["control", "ancilla"], product_to_measure=PauliString(string=(PauliChar.Z, PauliChar.Z)), tag="MZZ_ac")))
program.add_operation(QProgOperation(name="MXX_ct", length=1, targets=[aq, tq], implementation=RSCSurgery(targets=["ancilla", "target"], product_to_measure=PauliString(string=(PauliChar.X, PauliChar.X)), tag="MXX_ct")))
program.add_operation(QProgOperation(name="LZ_control", length=1, targets=[cq], implementation=ReadoutCode(targets=["control_patch"], tag="LZ_control")))
program.add_operation(QProgOperation(name="LZ_ancilla", length=1, targets=[aq], implementation=ReadoutCode(targets=["ancilla_patch"], tag="LZ_ancilla")))
program.add_operation(QProgOperation(name="LZ_target", length=1, targets=[tq], implementation=ReadoutCode(targets=["target_patch"], tag="LZ_target")))


draw_quantum_program(program, output_path="RSC_Surgery_Example.png")

# %% [markdown]
# The first three instructions do not do anything at the circuit level; they are used to define logical qubits on the chosen code and assign them to physical qubits. Then we have three instructions to initialize the codes in the chosen eigenstates, followed by our Pauli-product measurements, and finally we read out the codes in the Z basis. The last three instructions are used to free space in physical-qubit memory so that the qubits can be used for something else in later operations.
#
# When compiled, each operational `QECGadget` is transformed into a lower-level type of instruction that we call `QECPrimitives`, and it also produces two types of information:
# - `Observable`s: sets of physical measurements that have some kind of logical meaning, for example, `RSCSurgery` produces an observable that corresponds to the outcome of the Pauli-operator measurement.
# - `LogicalOperatorUpdate`: a gadget's computation can modify the logical operators, so some corrections, such as sets of physical measurements or changes in the physical assignment of qubits, may be necessary in order to preserve the expected logical state.
#
# Although gadgets can transform the shape of the stabilizer codes internally by merging, splitting, and so on, the structures of the stabilizer codes should be restored, and the same logical qubits must still be supported on them, up to corrections if necessary.
#
# `QECPrimitives` describe operations that are applied to a Tanner-graph structure. They exist to allow customizable circuits for lower-level QEC operations. So far, EPIC-QEC supports four primitives:
# - Syndrome measurement (extraction): how to perform a given number of rounds of stabilizer measurement.
# - FT readout: how to read out a code in a fault-tolerant way.
# - Apply gates: simply apply some physical gates to the targeted nodes.
# - Custom primitive: allows for broader ideas.
#
# `RSCSurgery` can be described by the following pseudo-code:
# ```python
# anc_qubits = ...
# merged_structure = create_merged_graph(left_code, right_code, anc_qubits)
#
# primitives = [
#     ApplyGates(anc_qubits, "RZ")
#     ExtractSyndrome(merged_structure, distance=d)
#     Readout(anc_qubits)
#     ExtractSyndrome(left_code, distance=d)
#     ExtractSyndrome(right_code, distance=d)
# ]
# ```
#
# Primitives are compiled into circuit-level instructions and produce sets of physical measurements as well as information related to detectors. The implementation used for each primitive can be chosen in the compilation configuration, which is a JSON object as shown below. Here we use the specific syndrome schedule for surface codes, and the default simplest way of applying gates and reading out. The config also includes an objective distance that we want to achieve in our computation; this is typically used to set how many rounds of syndrome measurements need to be performed.

# %%
config = {
    "primitives": {
        "epic.core.qec_primitives.interfaces.ApplyGate": "epic.modules.qec_primitives.SimpleGateApplication",
        "epic.core.qec_primitives.interfaces.Readout": "epic.modules.qec_primitives.NaiveReadout",
        "epic.core.qec_primitives.interfaces.ExtractSyndrome": "epic.modules.qec_primitives.RSCSyndromeExtraction",
    },
    "objective_distance": 3,
}

# %% [markdown]
# We can then create our compiler with this config and compile our program. The outcome of `.compile(program)` is a `CompiledExperiment` object. It contains the instructions, detectors, and observables as defined by the gadgets. In Stim, we need to declare deterministic observables in order to simulate properly. Furthermore, we still need to add the feedforward corrections for our CNOT to be complete. This is done by calling `.to_stim_program()` and providing the observables we want. Here, the outcome of the ZZ measurement and the ancilla readout are added to the target readout in order to match the definition of the CNOT, as well as a `NoiseModel`.

# %%
from pathlib import Path

import stim

from epic import QECCompiler, StimLikeNoiseModel

compiler = QECCompiler(config)

# compiled_program = compiler.compile(program, visual_output_path=Path("visualizations/getting_started/comp_vis.pdf"))
compiled_program = compiler.compile(program)

noise = 0.1
noise_model = StimLikeNoiseModel.from_stim_like_probabilities(
    after_clifford_depolarization=noise,
    after_reset_flip_probability=noise,
    before_measure_flip_probability=noise,
    before_round_data_depolarization=noise,
)

stim_observables = [["readout_LZ_control_rsc2_lq_0"], ["rsc_surgery_MZZ_ac", "readout_LZ_ancilla_rsc1_lq_0", "readout_LZ_target_rsc3_lq_0"]]

# draw_quantum_program(compiled_program.program)

stim_program = compiled_program.to_stim_program(stim_observables, noise_model=noise_model)

print(stim_program)
print(len(stim.Circuit(stim_program).shortest_graphlike_error(ignore_ungraphlike_errors=True)))
# Out:
# RZ 6 5 2 3 8 0 4 1 7
# X_ERROR(0.1) 6 5 2 3 8 0 4 1 7
# RZ 32
# X_ERROR(0.1) 32
# RZ 33
# X_ERROR(0.1) 33
# RZ 30
# X_ERROR(0.1) 30
# RZ 28
# X_ERROR(0.1) 28
# RZ 31
# X_ERROR(0.1) 31
# RZ 27
# X_ERROR(0.1) 27
# RZ 34
# X_ERROR(0.1) 34
# RZ 29
# X_ERROR(0.1) 29
# RZ 12 9 14 15 10 17 11 16 13
# X_ERROR(0.1) 12 9 14 15 10 17 11 16 13
# RZ 38
# X_ERROR(0.1) 38
# RZ 39
# X_ERROR(0.1) 39
# RZ 42
# X_ERROR(0.1) 42
# RZ 35
# X_ERROR(0.1) 35
# RZ 37
# X_ERROR(0.1) 37
# RZ 40
# X_ERROR(0.1) 40
# RZ 41
# X_ERROR(0.1) 41
# RZ 36
# X_ERROR(0.1) 36
# RZ 18 25 21 19 24 23 20 26 22
# X_ERROR(0.1) 18 25 21 19 24 23 20 26 22
# RZ 49
# X_ERROR(0.1) 49
# RZ 44
# X_ERROR(0.1) 44
# RZ 50
# X_ERROR(0.1) 50
# RZ 45
# X_ERROR(0.1) 45
# RZ 48
# X_ERROR(0.1) 48
# RZ 46
# X_ERROR(0.1) 46
# RZ 47
# X_ERROR(0.1) 47
# RZ 43
# X_ERROR(0.1) 43
# TICK
# H 32
# DEPOLARIZE1(0.1) 32
# H 30
# DEPOLARIZE1(0.1) 30
# H 27
# DEPOLARIZE1(0.1) 27
# H 34
# DEPOLARIZE1(0.1) 34
# H 42
# DEPOLARIZE1(0.1) 42
# H 35
# DEPOLARIZE1(0.1) 35
# H 40
# DEPOLARIZE1(0.1) 40
# H 41
# DEPOLARIZE1(0.1) 41
# H 44
# DEPOLARIZE1(0.1) 44
# H 50
# DEPOLARIZE1(0.1) 50
# H 45
# DEPOLARIZE1(0.1) 45
# H 48
# DEPOLARIZE1(0.1) 48
# TICK
# CX 32 4
# DEPOLARIZE2(0.1) 32 4
# CX 3 33
# DEPOLARIZE2(0.1) 3 33
# CX 30 7
# DEPOLARIZE2(0.1) 30 7
# CX 6 28
# DEPOLARIZE2(0.1) 6 28
# CX 1 31
# DEPOLARIZE2(0.1) 1 31
# CX 34 2
# DEPOLARIZE2(0.1) 34 2
# CX 13 39
# DEPOLARIZE2(0.1) 13 39
# CX 35 11
# DEPOLARIZE2(0.1) 35 11
# CX 12 37
# DEPOLARIZE2(0.1) 12 37
# CX 40 14
# DEPOLARIZE2(0.1) 40 14
# CX 41 15
# DEPOLARIZE2(0.1) 41 15
# CX 9 36
# DEPOLARIZE2(0.1) 9 36
# CX 50 20
# DEPOLARIZE2(0.1) 50 20
# CX 45 21
# DEPOLARIZE2(0.1) 45 21
# CX 48 23
# DEPOLARIZE2(0.1) 48 23
# CX 22 46
# DEPOLARIZE2(0.1) 22 46
# CX 19 47
# DEPOLARIZE2(0.1) 19 47
# CX 25 43
# DEPOLARIZE2(0.1) 25 43
# TICK
# CX 32 8
# DEPOLARIZE2(0.1) 32 8
# CX 0 33
# DEPOLARIZE2(0.1) 0 33
# CX 30 3
# DEPOLARIZE2(0.1) 30 3
# CX 2 28
# DEPOLARIZE2(0.1) 2 28
# CX 4 31
# DEPOLARIZE2(0.1) 4 31
# CX 34 1
# DEPOLARIZE2(0.1) 34 1
# CX 16 39
# DEPOLARIZE2(0.1) 16 39
# CX 35 12
# DEPOLARIZE2(0.1) 35 12
# CX 14 37
# DEPOLARIZE2(0.1) 14 37
# CX 40 17
# DEPOLARIZE2(0.1) 40 17
# CX 41 13
# DEPOLARIZE2(0.1) 41 13
# CX 11 36
# DEPOLARIZE2(0.1) 11 36
# CX 50 19
# DEPOLARIZE2(0.1) 50 19
# CX 45 26
# DEPOLARIZE2(0.1) 45 26
# CX 48 22
# DEPOLARIZE2(0.1) 48 22
# CX 24 46
# DEPOLARIZE2(0.1) 24 46
# CX 21 47
# DEPOLARIZE2(0.1) 21 47
# CX 20 43
# DEPOLARIZE2(0.1) 20 43
# TICK
# CX 30 1
# DEPOLARIZE2(0.1) 30 1
# CX 7 28
# DEPOLARIZE2(0.1) 7 28
# CX 0 31
# DEPOLARIZE2(0.1) 0 31
# CX 27 6
# DEPOLARIZE2(0.1) 27 6
# CX 34 5
# DEPOLARIZE2(0.1) 34 5
# CX 2 29
# DEPOLARIZE2(0.1) 2 29
# CX 11 38
# DEPOLARIZE2(0.1) 11 38
# CX 42 9
# DEPOLARIZE2(0.1) 42 9
# CX 35 10
# DEPOLARIZE2(0.1) 35 10
# CX 16 37
# DEPOLARIZE2(0.1) 16 37
# CX 41 12
# DEPOLARIZE2(0.1) 41 12
# CX 15 36
# DEPOLARIZE2(0.1) 15 36
# CX 20 49
# DEPOLARIZE2(0.1) 20 49
# CX 44 25
# DEPOLARIZE2(0.1) 44 25
# CX 50 18
# DEPOLARIZE2(0.1) 50 18
# CX 48 19
# DEPOLARIZE2(0.1) 48 19
# CX 24 47
# DEPOLARIZE2(0.1) 24 47
# CX 23 43
# DEPOLARIZE2(0.1) 23 43
# TICK
# CX 30 0
# DEPOLARIZE2(0.1) 30 0
# CX 1 28
# DEPOLARIZE2(0.1) 1 28
# CX 8 31
# DEPOLARIZE2(0.1) 8 31
# CX 27 7
# DEPOLARIZE2(0.1) 27 7
# CX 34 4
# DEPOLARIZE2(0.1) 34 4
# CX 5 29
# DEPOLARIZE2(0.1) 5 29
# CX 10 38
# DEPOLARIZE2(0.1) 10 38
# CX 42 15
# DEPOLARIZE2(0.1) 42 15
# CX 35 14
# DEPOLARIZE2(0.1) 35 14
# CX 17 37
# DEPOLARIZE2(0.1) 17 37
# CX 41 16
# DEPOLARIZE2(0.1) 41 16
# CX 12 36
# DEPOLARIZE2(0.1) 12 36
# CX 18 49
# DEPOLARIZE2(0.1) 18 49
# CX 44 23
# DEPOLARIZE2(0.1) 44 23
# CX 50 21
# DEPOLARIZE2(0.1) 50 21
# CX 48 24
# DEPOLARIZE2(0.1) 48 24
# CX 26 47
# DEPOLARIZE2(0.1) 26 47
# CX 19 43
# DEPOLARIZE2(0.1) 19 43
# TICK
# H 32
# DEPOLARIZE1(0.1) 32
# H 30
# DEPOLARIZE1(0.1) 30
# H 27
# DEPOLARIZE1(0.1) 27
# H 34
# DEPOLARIZE1(0.1) 34
# H 42
# DEPOLARIZE1(0.1) 42
# H 35
# DEPOLARIZE1(0.1) 35
# H 40
# DEPOLARIZE1(0.1) 40
# H 41
# DEPOLARIZE1(0.1) 41
# H 44
# DEPOLARIZE1(0.1) 44
# H 50
# DEPOLARIZE1(0.1) 50
# H 45
# DEPOLARIZE1(0.1) 45
# H 48
# DEPOLARIZE1(0.1) 48
# TICK
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 28
# MRZ 28
# X_ERROR(0.1) 28
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 27
# MRZ 27
# X_ERROR(0.1) 27
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 38
# MRZ 38
# X_ERROR(0.1) 38
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 37
# MRZ 37
# X_ERROR(0.1) 37
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 41
# MRZ 41
# X_ERROR(0.1) 41
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# X_ERROR(0.1) 44
# MRZ 44
# X_ERROR(0.1) 44
# X_ERROR(0.1) 50
# MRZ 50
# X_ERROR(0.1) 50
# X_ERROR(0.1) 45
# MRZ 45
# X_ERROR(0.1) 45
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 47
# MRZ 47
# X_ERROR(0.1) 47
# X_ERROR(0.1) 43
# MRZ 43
# X_ERROR(0.1) 43
# TICK
# H 32
# DEPOLARIZE1(0.1) 32
# H 30
# DEPOLARIZE1(0.1) 30
# H 27
# DEPOLARIZE1(0.1) 27
# H 34
# DEPOLARIZE1(0.1) 34
# H 42
# DEPOLARIZE1(0.1) 42
# H 35
# DEPOLARIZE1(0.1) 35
# H 40
# DEPOLARIZE1(0.1) 40
# H 41
# DEPOLARIZE1(0.1) 41
# H 44
# DEPOLARIZE1(0.1) 44
# H 50
# DEPOLARIZE1(0.1) 50
# H 45
# DEPOLARIZE1(0.1) 45
# H 48
# DEPOLARIZE1(0.1) 48
# TICK
# CX 32 4
# DEPOLARIZE2(0.1) 32 4
# CX 3 33
# DEPOLARIZE2(0.1) 3 33
# CX 30 7
# DEPOLARIZE2(0.1) 30 7
# CX 6 28
# DEPOLARIZE2(0.1) 6 28
# CX 1 31
# DEPOLARIZE2(0.1) 1 31
# CX 34 2
# DEPOLARIZE2(0.1) 34 2
# CX 13 39
# DEPOLARIZE2(0.1) 13 39
# CX 35 11
# DEPOLARIZE2(0.1) 35 11
# CX 12 37
# DEPOLARIZE2(0.1) 12 37
# CX 40 14
# DEPOLARIZE2(0.1) 40 14
# CX 41 15
# DEPOLARIZE2(0.1) 41 15
# CX 9 36
# DEPOLARIZE2(0.1) 9 36
# CX 50 20
# DEPOLARIZE2(0.1) 50 20
# CX 45 21
# DEPOLARIZE2(0.1) 45 21
# CX 48 23
# DEPOLARIZE2(0.1) 48 23
# CX 22 46
# DEPOLARIZE2(0.1) 22 46
# CX 19 47
# DEPOLARIZE2(0.1) 19 47
# CX 25 43
# DEPOLARIZE2(0.1) 25 43
# TICK
# CX 32 8
# DEPOLARIZE2(0.1) 32 8
# CX 0 33
# DEPOLARIZE2(0.1) 0 33
# CX 30 3
# DEPOLARIZE2(0.1) 30 3
# CX 2 28
# DEPOLARIZE2(0.1) 2 28
# CX 4 31
# DEPOLARIZE2(0.1) 4 31
# CX 34 1
# DEPOLARIZE2(0.1) 34 1
# CX 16 39
# DEPOLARIZE2(0.1) 16 39
# CX 35 12
# DEPOLARIZE2(0.1) 35 12
# CX 14 37
# DEPOLARIZE2(0.1) 14 37
# CX 40 17
# DEPOLARIZE2(0.1) 40 17
# CX 41 13
# DEPOLARIZE2(0.1) 41 13
# CX 11 36
# DEPOLARIZE2(0.1) 11 36
# CX 50 19
# DEPOLARIZE2(0.1) 50 19
# CX 45 26
# DEPOLARIZE2(0.1) 45 26
# CX 48 22
# DEPOLARIZE2(0.1) 48 22
# CX 24 46
# DEPOLARIZE2(0.1) 24 46
# CX 21 47
# DEPOLARIZE2(0.1) 21 47
# CX 20 43
# DEPOLARIZE2(0.1) 20 43
# TICK
# CX 30 1
# DEPOLARIZE2(0.1) 30 1
# CX 7 28
# DEPOLARIZE2(0.1) 7 28
# CX 0 31
# DEPOLARIZE2(0.1) 0 31
# CX 27 6
# DEPOLARIZE2(0.1) 27 6
# CX 34 5
# DEPOLARIZE2(0.1) 34 5
# CX 2 29
# DEPOLARIZE2(0.1) 2 29
# CX 11 38
# DEPOLARIZE2(0.1) 11 38
# CX 42 9
# DEPOLARIZE2(0.1) 42 9
# CX 35 10
# DEPOLARIZE2(0.1) 35 10
# CX 16 37
# DEPOLARIZE2(0.1) 16 37
# CX 41 12
# DEPOLARIZE2(0.1) 41 12
# CX 15 36
# DEPOLARIZE2(0.1) 15 36
# CX 20 49
# DEPOLARIZE2(0.1) 20 49
# CX 44 25
# DEPOLARIZE2(0.1) 44 25
# CX 50 18
# DEPOLARIZE2(0.1) 50 18
# CX 48 19
# DEPOLARIZE2(0.1) 48 19
# CX 24 47
# DEPOLARIZE2(0.1) 24 47
# CX 23 43
# DEPOLARIZE2(0.1) 23 43
# TICK
# CX 30 0
# DEPOLARIZE2(0.1) 30 0
# CX 1 28
# DEPOLARIZE2(0.1) 1 28
# CX 8 31
# DEPOLARIZE2(0.1) 8 31
# CX 27 7
# DEPOLARIZE2(0.1) 27 7
# CX 34 4
# DEPOLARIZE2(0.1) 34 4
# CX 5 29
# DEPOLARIZE2(0.1) 5 29
# CX 10 38
# DEPOLARIZE2(0.1) 10 38
# CX 42 15
# DEPOLARIZE2(0.1) 42 15
# CX 35 14
# DEPOLARIZE2(0.1) 35 14
# CX 17 37
# DEPOLARIZE2(0.1) 17 37
# CX 41 16
# DEPOLARIZE2(0.1) 41 16
# CX 12 36
# DEPOLARIZE2(0.1) 12 36
# CX 18 49
# DEPOLARIZE2(0.1) 18 49
# CX 44 23
# DEPOLARIZE2(0.1) 44 23
# CX 50 21
# DEPOLARIZE2(0.1) 50 21
# CX 48 24
# DEPOLARIZE2(0.1) 48 24
# CX 26 47
# DEPOLARIZE2(0.1) 26 47
# CX 19 43
# DEPOLARIZE2(0.1) 19 43
# TICK
# H 32
# DEPOLARIZE1(0.1) 32
# H 30
# DEPOLARIZE1(0.1) 30
# H 27
# DEPOLARIZE1(0.1) 27
# H 34
# DEPOLARIZE1(0.1) 34
# H 42
# DEPOLARIZE1(0.1) 42
# H 35
# DEPOLARIZE1(0.1) 35
# H 40
# DEPOLARIZE1(0.1) 40
# H 41
# DEPOLARIZE1(0.1) 41
# H 44
# DEPOLARIZE1(0.1) 44
# H 50
# DEPOLARIZE1(0.1) 50
# H 45
# DEPOLARIZE1(0.1) 45
# H 48
# DEPOLARIZE1(0.1) 48
# TICK
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 28
# MRZ 28
# X_ERROR(0.1) 28
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 27
# MRZ 27
# X_ERROR(0.1) 27
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 38
# MRZ 38
# X_ERROR(0.1) 38
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 37
# MRZ 37
# X_ERROR(0.1) 37
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 41
# MRZ 41
# X_ERROR(0.1) 41
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# X_ERROR(0.1) 44
# MRZ 44
# X_ERROR(0.1) 44
# X_ERROR(0.1) 50
# MRZ 50
# X_ERROR(0.1) 50
# X_ERROR(0.1) 45
# MRZ 45
# X_ERROR(0.1) 45
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 47
# MRZ 47
# X_ERROR(0.1) 47
# X_ERROR(0.1) 43
# MRZ 43
# X_ERROR(0.1) 43
# TICK
# H 32
# DEPOLARIZE1(0.1) 32
# H 30
# DEPOLARIZE1(0.1) 30
# H 27
# DEPOLARIZE1(0.1) 27
# H 34
# DEPOLARIZE1(0.1) 34
# H 42
# DEPOLARIZE1(0.1) 42
# H 35
# DEPOLARIZE1(0.1) 35
# H 40
# DEPOLARIZE1(0.1) 40
# H 41
# DEPOLARIZE1(0.1) 41
# H 44
# DEPOLARIZE1(0.1) 44
# H 50
# DEPOLARIZE1(0.1) 50
# H 45
# DEPOLARIZE1(0.1) 45
# H 48
# DEPOLARIZE1(0.1) 48
# TICK
# CX 32 4
# DEPOLARIZE2(0.1) 32 4
# CX 3 33
# DEPOLARIZE2(0.1) 3 33
# CX 30 7
# DEPOLARIZE2(0.1) 30 7
# CX 6 28
# DEPOLARIZE2(0.1) 6 28
# CX 1 31
# DEPOLARIZE2(0.1) 1 31
# CX 34 2
# DEPOLARIZE2(0.1) 34 2
# CX 13 39
# DEPOLARIZE2(0.1) 13 39
# CX 35 11
# DEPOLARIZE2(0.1) 35 11
# CX 12 37
# DEPOLARIZE2(0.1) 12 37
# CX 40 14
# DEPOLARIZE2(0.1) 40 14
# CX 41 15
# DEPOLARIZE2(0.1) 41 15
# CX 9 36
# DEPOLARIZE2(0.1) 9 36
# CX 50 20
# DEPOLARIZE2(0.1) 50 20
# CX 45 21
# DEPOLARIZE2(0.1) 45 21
# CX 48 23
# DEPOLARIZE2(0.1) 48 23
# CX 22 46
# DEPOLARIZE2(0.1) 22 46
# CX 19 47
# DEPOLARIZE2(0.1) 19 47
# CX 25 43
# DEPOLARIZE2(0.1) 25 43
# TICK
# CX 32 8
# DEPOLARIZE2(0.1) 32 8
# CX 0 33
# DEPOLARIZE2(0.1) 0 33
# CX 30 3
# DEPOLARIZE2(0.1) 30 3
# CX 2 28
# DEPOLARIZE2(0.1) 2 28
# CX 4 31
# DEPOLARIZE2(0.1) 4 31
# CX 34 1
# DEPOLARIZE2(0.1) 34 1
# CX 16 39
# DEPOLARIZE2(0.1) 16 39
# CX 35 12
# DEPOLARIZE2(0.1) 35 12
# CX 14 37
# DEPOLARIZE2(0.1) 14 37
# CX 40 17
# DEPOLARIZE2(0.1) 40 17
# CX 41 13
# DEPOLARIZE2(0.1) 41 13
# CX 11 36
# DEPOLARIZE2(0.1) 11 36
# CX 50 19
# DEPOLARIZE2(0.1) 50 19
# CX 45 26
# DEPOLARIZE2(0.1) 45 26
# CX 48 22
# DEPOLARIZE2(0.1) 48 22
# CX 24 46
# DEPOLARIZE2(0.1) 24 46
# CX 21 47
# DEPOLARIZE2(0.1) 21 47
# CX 20 43
# DEPOLARIZE2(0.1) 20 43
# TICK
# CX 30 1
# DEPOLARIZE2(0.1) 30 1
# CX 7 28
# DEPOLARIZE2(0.1) 7 28
# CX 0 31
# DEPOLARIZE2(0.1) 0 31
# CX 27 6
# DEPOLARIZE2(0.1) 27 6
# CX 34 5
# DEPOLARIZE2(0.1) 34 5
# CX 2 29
# DEPOLARIZE2(0.1) 2 29
# CX 11 38
# DEPOLARIZE2(0.1) 11 38
# CX 42 9
# DEPOLARIZE2(0.1) 42 9
# CX 35 10
# DEPOLARIZE2(0.1) 35 10
# CX 16 37
# DEPOLARIZE2(0.1) 16 37
# CX 41 12
# DEPOLARIZE2(0.1) 41 12
# CX 15 36
# DEPOLARIZE2(0.1) 15 36
# CX 20 49
# DEPOLARIZE2(0.1) 20 49
# CX 44 25
# DEPOLARIZE2(0.1) 44 25
# CX 50 18
# DEPOLARIZE2(0.1) 50 18
# CX 48 19
# DEPOLARIZE2(0.1) 48 19
# CX 24 47
# DEPOLARIZE2(0.1) 24 47
# CX 23 43
# DEPOLARIZE2(0.1) 23 43
# TICK
# CX 30 0
# DEPOLARIZE2(0.1) 30 0
# CX 1 28
# DEPOLARIZE2(0.1) 1 28
# CX 8 31
# DEPOLARIZE2(0.1) 8 31
# CX 27 7
# DEPOLARIZE2(0.1) 27 7
# CX 34 4
# DEPOLARIZE2(0.1) 34 4
# CX 5 29
# DEPOLARIZE2(0.1) 5 29
# CX 10 38
# DEPOLARIZE2(0.1) 10 38
# CX 42 15
# DEPOLARIZE2(0.1) 42 15
# CX 35 14
# DEPOLARIZE2(0.1) 35 14
# CX 17 37
# DEPOLARIZE2(0.1) 17 37
# CX 41 16
# DEPOLARIZE2(0.1) 41 16
# CX 12 36
# DEPOLARIZE2(0.1) 12 36
# CX 18 49
# DEPOLARIZE2(0.1) 18 49
# CX 44 23
# DEPOLARIZE2(0.1) 44 23
# CX 50 21
# DEPOLARIZE2(0.1) 50 21
# CX 48 24
# DEPOLARIZE2(0.1) 48 24
# CX 26 47
# DEPOLARIZE2(0.1) 26 47
# CX 19 43
# DEPOLARIZE2(0.1) 19 43
# TICK
# H 32
# DEPOLARIZE1(0.1) 32
# H 30
# DEPOLARIZE1(0.1) 30
# H 27
# DEPOLARIZE1(0.1) 27
# H 34
# DEPOLARIZE1(0.1) 34
# H 42
# DEPOLARIZE1(0.1) 42
# H 35
# DEPOLARIZE1(0.1) 35
# H 40
# DEPOLARIZE1(0.1) 40
# H 41
# DEPOLARIZE1(0.1) 41
# H 44
# DEPOLARIZE1(0.1) 44
# H 50
# DEPOLARIZE1(0.1) 50
# H 45
# DEPOLARIZE1(0.1) 45
# H 48
# DEPOLARIZE1(0.1) 48
# TICK
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 28
# MRZ 28
# X_ERROR(0.1) 28
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 27
# MRZ 27
# X_ERROR(0.1) 27
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 38
# MRZ 38
# X_ERROR(0.1) 38
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 37
# MRZ 37
# X_ERROR(0.1) 37
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 41
# MRZ 41
# X_ERROR(0.1) 41
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# X_ERROR(0.1) 44
# MRZ 44
# X_ERROR(0.1) 44
# X_ERROR(0.1) 50
# MRZ 50
# X_ERROR(0.1) 50
# X_ERROR(0.1) 45
# MRZ 45
# X_ERROR(0.1) 45
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 47
# MRZ 47
# X_ERROR(0.1) 47
# X_ERROR(0.1) 43
# MRZ 43
# X_ERROR(0.1) 43
# TICK
# RX 27 38 41 37 50 43 47
# Z_ERROR(0.1) 27 38 41 37 50 43 47
# RZ 35
# X_ERROR(0.1) 35
# RZ 30
# X_ERROR(0.1) 30
# RZ 28
# X_ERROR(0.1) 28
# RZ 31
# X_ERROR(0.1) 31
# RZ 36
# X_ERROR(0.1) 36
# RZ 32
# X_ERROR(0.1) 32
# RZ 33
# X_ERROR(0.1) 33
# RZ 49
# X_ERROR(0.1) 49
# RZ 29
# X_ERROR(0.1) 29
# RZ 40
# X_ERROR(0.1) 40
# RZ 46
# X_ERROR(0.1) 46
# RZ 48
# X_ERROR(0.1) 48
# RZ 39
# X_ERROR(0.1) 39
# RZ 44
# X_ERROR(0.1) 44
# RZ 42
# X_ERROR(0.1) 42
# RZ 34
# X_ERROR(0.1) 34
# RZ 45
# X_ERROR(0.1) 45
# TICK
# RZ 50
# X_ERROR(0.1) 50
# RZ 47
# X_ERROR(0.1) 47
# RZ 27
# X_ERROR(0.1) 27
# RZ 41
# X_ERROR(0.1) 41
# TICK
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 29
# DEPOLARIZE1(0.1) 29
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 42
# DEPOLARIZE1(0.1) 42
# TICK
# CX 5 50
# DEPOLARIZE2(0.1) 5 50
# CX 12 35
# DEPOLARIZE2(0.1) 12 35
# CX 9 30
# DEPOLARIZE2(0.1) 9 30
# CX 28 4
# DEPOLARIZE2(0.1) 28 4
# CX 31 7
# DEPOLARIZE2(0.1) 31 7
# CX 6 36
# DEPOLARIZE2(0.1) 6 36
# CX 1 32
# DEPOLARIZE2(0.1) 1 32
# CX 33 43
# DEPOLARIZE2(0.1) 33 43
# CX 49 11
# DEPOLARIZE2(0.1) 49 11
# CX 29 2
# DEPOLARIZE2(0.1) 29 2
# CX 46 14
# DEPOLARIZE2(0.1) 46 14
# CX 48 15
# DEPOLARIZE2(0.1) 48 15
# CX 3 44
# DEPOLARIZE2(0.1) 3 44
# CX 8 27
# DEPOLARIZE2(0.1) 8 27
# CX 13 34
# DEPOLARIZE2(0.1) 13 34
# CX 38 41
# DEPOLARIZE2(0.1) 38 41
# TICK
# CX 43 50
# DEPOLARIZE2(0.1) 43 50
# CX 14 35
# DEPOLARIZE2(0.1) 14 35
# CX 11 30
# DEPOLARIZE2(0.1) 11 30
# CX 28 8
# DEPOLARIZE2(0.1) 28 8
# CX 31 3
# DEPOLARIZE2(0.1) 31 3
# CX 2 36
# DEPOLARIZE2(0.1) 2 36
# CX 4 32
# DEPOLARIZE2(0.1) 4 32
# CX 33 38
# DEPOLARIZE2(0.1) 33 38
# CX 49 12
# DEPOLARIZE2(0.1) 49 12
# CX 29 1
# DEPOLARIZE2(0.1) 29 1
# CX 46 17
# DEPOLARIZE2(0.1) 46 17
# CX 48 13
# DEPOLARIZE2(0.1) 48 13
# CX 0 44
# DEPOLARIZE2(0.1) 0 44
# CX 37 27
# DEPOLARIZE2(0.1) 37 27
# CX 16 34
# DEPOLARIZE2(0.1) 16 34
# CX 15 41
# DEPOLARIZE2(0.1) 15 41
# TICK
# CX 4 50
# DEPOLARIZE2(0.1) 4 50
# CX 16 35
# DEPOLARIZE2(0.1) 16 35
# CX 15 30
# DEPOLARIZE2(0.1) 15 30
# CX 28 38
# DEPOLARIZE2(0.1) 28 38
# CX 31 1
# DEPOLARIZE2(0.1) 31 1
# CX 7 36
# DEPOLARIZE2(0.1) 7 36
# CX 0 32
# DEPOLARIZE2(0.1) 0 32
# CX 33 9
# DEPOLARIZE2(0.1) 33 9
# CX 43 47
# DEPOLARIZE2(0.1) 43 47
# CX 49 10
# DEPOLARIZE2(0.1) 49 10
# CX 29 5
# DEPOLARIZE2(0.1) 29 5
# CX 2 40
# DEPOLARIZE2(0.1) 2 40
# CX 48 12
# DEPOLARIZE2(0.1) 48 12
# CX 11 39
# DEPOLARIZE2(0.1) 11 39
# CX 42 6
# DEPOLARIZE2(0.1) 42 6
# CX 37 41
# DEPOLARIZE2(0.1) 37 41
# TICK
# CX 38 50
# DEPOLARIZE2(0.1) 38 50
# CX 17 35
# DEPOLARIZE2(0.1) 17 35
# CX 12 30
# DEPOLARIZE2(0.1) 12 30
# CX 28 37
# DEPOLARIZE2(0.1) 28 37
# CX 31 0
# DEPOLARIZE2(0.1) 31 0
# CX 1 36
# DEPOLARIZE2(0.1) 1 36
# CX 8 32
# DEPOLARIZE2(0.1) 8 32
# CX 33 15
# DEPOLARIZE2(0.1) 33 15
# CX 9 47
# DEPOLARIZE2(0.1) 9 47
# CX 49 14
# DEPOLARIZE2(0.1) 49 14
# CX 29 4
# DEPOLARIZE2(0.1) 29 4
# CX 5 40
# DEPOLARIZE2(0.1) 5 40
# CX 48 16
# DEPOLARIZE2(0.1) 48 16
# CX 10 39
# DEPOLARIZE2(0.1) 10 39
# CX 42 7
# DEPOLARIZE2(0.1) 42 7
# CX 13 41
# DEPOLARIZE2(0.1) 13 41
# TICK
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 29
# DEPOLARIZE1(0.1) 29
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 42
# DEPOLARIZE1(0.1) 42
# TICK
# X_ERROR(0.1) 50
# MRZ 50
# X_ERROR(0.1) 50
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 28
# MRZ 28
# X_ERROR(0.1) 28
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 47
# MRZ 47
# X_ERROR(0.1) 47
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 44
# MRZ 44
# X_ERROR(0.1) 44
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 27
# MRZ 27
# X_ERROR(0.1) 27
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 41
# MRZ 41
# X_ERROR(0.1) 41
# TICK
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 29
# DEPOLARIZE1(0.1) 29
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 42
# DEPOLARIZE1(0.1) 42
# TICK
# CX 5 50
# DEPOLARIZE2(0.1) 5 50
# CX 12 35
# DEPOLARIZE2(0.1) 12 35
# CX 9 30
# DEPOLARIZE2(0.1) 9 30
# CX 28 4
# DEPOLARIZE2(0.1) 28 4
# CX 31 7
# DEPOLARIZE2(0.1) 31 7
# CX 6 36
# DEPOLARIZE2(0.1) 6 36
# CX 1 32
# DEPOLARIZE2(0.1) 1 32
# CX 33 43
# DEPOLARIZE2(0.1) 33 43
# CX 49 11
# DEPOLARIZE2(0.1) 49 11
# CX 29 2
# DEPOLARIZE2(0.1) 29 2
# CX 46 14
# DEPOLARIZE2(0.1) 46 14
# CX 48 15
# DEPOLARIZE2(0.1) 48 15
# CX 3 44
# DEPOLARIZE2(0.1) 3 44
# CX 8 27
# DEPOLARIZE2(0.1) 8 27
# CX 13 34
# DEPOLARIZE2(0.1) 13 34
# CX 38 41
# DEPOLARIZE2(0.1) 38 41
# TICK
# CX 43 50
# DEPOLARIZE2(0.1) 43 50
# CX 14 35
# DEPOLARIZE2(0.1) 14 35
# CX 11 30
# DEPOLARIZE2(0.1) 11 30
# CX 28 8
# DEPOLARIZE2(0.1) 28 8
# CX 31 3
# DEPOLARIZE2(0.1) 31 3
# CX 2 36
# DEPOLARIZE2(0.1) 2 36
# CX 4 32
# DEPOLARIZE2(0.1) 4 32
# CX 33 38
# DEPOLARIZE2(0.1) 33 38
# CX 49 12
# DEPOLARIZE2(0.1) 49 12
# CX 29 1
# DEPOLARIZE2(0.1) 29 1
# CX 46 17
# DEPOLARIZE2(0.1) 46 17
# CX 48 13
# DEPOLARIZE2(0.1) 48 13
# CX 0 44
# DEPOLARIZE2(0.1) 0 44
# CX 37 27
# DEPOLARIZE2(0.1) 37 27
# CX 16 34
# DEPOLARIZE2(0.1) 16 34
# CX 15 41
# DEPOLARIZE2(0.1) 15 41
# TICK
# CX 4 50
# DEPOLARIZE2(0.1) 4 50
# CX 16 35
# DEPOLARIZE2(0.1) 16 35
# CX 15 30
# DEPOLARIZE2(0.1) 15 30
# CX 28 38
# DEPOLARIZE2(0.1) 28 38
# CX 31 1
# DEPOLARIZE2(0.1) 31 1
# CX 7 36
# DEPOLARIZE2(0.1) 7 36
# CX 0 32
# DEPOLARIZE2(0.1) 0 32
# CX 33 9
# DEPOLARIZE2(0.1) 33 9
# CX 43 47
# DEPOLARIZE2(0.1) 43 47
# CX 49 10
# DEPOLARIZE2(0.1) 49 10
# CX 29 5
# DEPOLARIZE2(0.1) 29 5
# CX 2 40
# DEPOLARIZE2(0.1) 2 40
# CX 48 12
# DEPOLARIZE2(0.1) 48 12
# CX 11 39
# DEPOLARIZE2(0.1) 11 39
# CX 42 6
# DEPOLARIZE2(0.1) 42 6
# CX 37 41
# DEPOLARIZE2(0.1) 37 41
# TICK
# CX 38 50
# DEPOLARIZE2(0.1) 38 50
# CX 17 35
# DEPOLARIZE2(0.1) 17 35
# CX 12 30
# DEPOLARIZE2(0.1) 12 30
# CX 28 37
# DEPOLARIZE2(0.1) 28 37
# CX 31 0
# DEPOLARIZE2(0.1) 31 0
# CX 1 36
# DEPOLARIZE2(0.1) 1 36
# CX 8 32
# DEPOLARIZE2(0.1) 8 32
# CX 33 15
# DEPOLARIZE2(0.1) 33 15
# CX 9 47
# DEPOLARIZE2(0.1) 9 47
# CX 49 14
# DEPOLARIZE2(0.1) 49 14
# CX 29 4
# DEPOLARIZE2(0.1) 29 4
# CX 5 40
# DEPOLARIZE2(0.1) 5 40
# CX 48 16
# DEPOLARIZE2(0.1) 48 16
# CX 10 39
# DEPOLARIZE2(0.1) 10 39
# CX 42 7
# DEPOLARIZE2(0.1) 42 7
# CX 13 41
# DEPOLARIZE2(0.1) 13 41
# TICK
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 29
# DEPOLARIZE1(0.1) 29
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 42
# DEPOLARIZE1(0.1) 42
# TICK
# X_ERROR(0.1) 50
# MRZ 50
# X_ERROR(0.1) 50
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 28
# MRZ 28
# X_ERROR(0.1) 28
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 47
# MRZ 47
# X_ERROR(0.1) 47
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 44
# MRZ 44
# X_ERROR(0.1) 44
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 27
# MRZ 27
# X_ERROR(0.1) 27
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 41
# MRZ 41
# X_ERROR(0.1) 41
# TICK
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 29
# DEPOLARIZE1(0.1) 29
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 42
# DEPOLARIZE1(0.1) 42
# TICK
# CX 5 50
# DEPOLARIZE2(0.1) 5 50
# CX 12 35
# DEPOLARIZE2(0.1) 12 35
# CX 9 30
# DEPOLARIZE2(0.1) 9 30
# CX 28 4
# DEPOLARIZE2(0.1) 28 4
# CX 31 7
# DEPOLARIZE2(0.1) 31 7
# CX 6 36
# DEPOLARIZE2(0.1) 6 36
# CX 1 32
# DEPOLARIZE2(0.1) 1 32
# CX 33 43
# DEPOLARIZE2(0.1) 33 43
# CX 49 11
# DEPOLARIZE2(0.1) 49 11
# CX 29 2
# DEPOLARIZE2(0.1) 29 2
# CX 46 14
# DEPOLARIZE2(0.1) 46 14
# CX 48 15
# DEPOLARIZE2(0.1) 48 15
# CX 3 44
# DEPOLARIZE2(0.1) 3 44
# CX 8 27
# DEPOLARIZE2(0.1) 8 27
# CX 13 34
# DEPOLARIZE2(0.1) 13 34
# CX 38 41
# DEPOLARIZE2(0.1) 38 41
# TICK
# CX 43 50
# DEPOLARIZE2(0.1) 43 50
# CX 14 35
# DEPOLARIZE2(0.1) 14 35
# CX 11 30
# DEPOLARIZE2(0.1) 11 30
# CX 28 8
# DEPOLARIZE2(0.1) 28 8
# CX 31 3
# DEPOLARIZE2(0.1) 31 3
# CX 2 36
# DEPOLARIZE2(0.1) 2 36
# CX 4 32
# DEPOLARIZE2(0.1) 4 32
# CX 33 38
# DEPOLARIZE2(0.1) 33 38
# CX 49 12
# DEPOLARIZE2(0.1) 49 12
# CX 29 1
# DEPOLARIZE2(0.1) 29 1
# CX 46 17
# DEPOLARIZE2(0.1) 46 17
# CX 48 13
# DEPOLARIZE2(0.1) 48 13
# CX 0 44
# DEPOLARIZE2(0.1) 0 44
# CX 37 27
# DEPOLARIZE2(0.1) 37 27
# CX 16 34
# DEPOLARIZE2(0.1) 16 34
# CX 15 41
# DEPOLARIZE2(0.1) 15 41
# TICK
# CX 4 50
# DEPOLARIZE2(0.1) 4 50
# CX 16 35
# DEPOLARIZE2(0.1) 16 35
# CX 15 30
# DEPOLARIZE2(0.1) 15 30
# CX 28 38
# DEPOLARIZE2(0.1) 28 38
# CX 31 1
# DEPOLARIZE2(0.1) 31 1
# CX 7 36
# DEPOLARIZE2(0.1) 7 36
# CX 0 32
# DEPOLARIZE2(0.1) 0 32
# CX 33 9
# DEPOLARIZE2(0.1) 33 9
# CX 43 47
# DEPOLARIZE2(0.1) 43 47
# CX 49 10
# DEPOLARIZE2(0.1) 49 10
# CX 29 5
# DEPOLARIZE2(0.1) 29 5
# CX 2 40
# DEPOLARIZE2(0.1) 2 40
# CX 48 12
# DEPOLARIZE2(0.1) 48 12
# CX 11 39
# DEPOLARIZE2(0.1) 11 39
# CX 42 6
# DEPOLARIZE2(0.1) 42 6
# CX 37 41
# DEPOLARIZE2(0.1) 37 41
# TICK
# CX 38 50
# DEPOLARIZE2(0.1) 38 50
# CX 17 35
# DEPOLARIZE2(0.1) 17 35
# CX 12 30
# DEPOLARIZE2(0.1) 12 30
# CX 28 37
# DEPOLARIZE2(0.1) 28 37
# CX 31 0
# DEPOLARIZE2(0.1) 31 0
# CX 1 36
# DEPOLARIZE2(0.1) 1 36
# CX 8 32
# DEPOLARIZE2(0.1) 8 32
# CX 33 15
# DEPOLARIZE2(0.1) 33 15
# CX 9 47
# DEPOLARIZE2(0.1) 9 47
# CX 49 14
# DEPOLARIZE2(0.1) 49 14
# CX 29 4
# DEPOLARIZE2(0.1) 29 4
# CX 5 40
# DEPOLARIZE2(0.1) 5 40
# CX 48 16
# DEPOLARIZE2(0.1) 48 16
# CX 10 39
# DEPOLARIZE2(0.1) 10 39
# CX 42 7
# DEPOLARIZE2(0.1) 42 7
# CX 13 41
# DEPOLARIZE2(0.1) 13 41
# TICK
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 29
# DEPOLARIZE1(0.1) 29
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 42
# DEPOLARIZE1(0.1) 42
# TICK
# X_ERROR(0.1) 50
# MRZ 50
# X_ERROR(0.1) 50
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 28
# MRZ 28
# X_ERROR(0.1) 28
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 47
# MRZ 47
# X_ERROR(0.1) 47
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 44
# MRZ 44
# X_ERROR(0.1) 44
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 27
# MRZ 27
# X_ERROR(0.1) 27
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 41
# MRZ 41
# X_ERROR(0.1) 41
# Z_ERROR(0.1) 37
# MX 37
# Z_ERROR(0.1) 38
# MX 38
# Z_ERROR(0.1) 43
# MX 43
# TICK
# RZ 39
# X_ERROR(0.1) 39
# RZ 34
# X_ERROR(0.1) 34
# RZ 33
# X_ERROR(0.1) 33
# RZ 49
# X_ERROR(0.1) 49
# RZ 35
# X_ERROR(0.1) 35
# RZ 46
# X_ERROR(0.1) 46
# RZ 48
# X_ERROR(0.1) 48
# RZ 30
# X_ERROR(0.1) 30
# RZ 28
# X_ERROR(0.1) 28
# RZ 44
# X_ERROR(0.1) 44
# RZ 31
# X_ERROR(0.1) 31
# RZ 36
# X_ERROR(0.1) 36
# RZ 32
# X_ERROR(0.1) 32
# RZ 42
# X_ERROR(0.1) 42
# RZ 29
# X_ERROR(0.1) 29
# RZ 40
# X_ERROR(0.1) 40
# RZ 37
# X_ERROR(0.1) 37
# RZ 41
# X_ERROR(0.1) 41
# RZ 50
# X_ERROR(0.1) 50
# RZ 27
# X_ERROR(0.1) 27
# RZ 47
# X_ERROR(0.1) 47
# TICK
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 42
# DEPOLARIZE1(0.1) 42
# H 29
# DEPOLARIZE1(0.1) 29
# TICK
# CX 13 34
# DEPOLARIZE2(0.1) 13 34
# CX 49 11
# DEPOLARIZE2(0.1) 49 11
# CX 12 35
# DEPOLARIZE2(0.1) 12 35
# CX 46 14
# DEPOLARIZE2(0.1) 46 14
# CX 48 15
# DEPOLARIZE2(0.1) 48 15
# CX 9 30
# DEPOLARIZE2(0.1) 9 30
# CX 28 4
# DEPOLARIZE2(0.1) 28 4
# CX 3 44
# DEPOLARIZE2(0.1) 3 44
# CX 31 7
# DEPOLARIZE2(0.1) 31 7
# CX 6 36
# DEPOLARIZE2(0.1) 6 36
# CX 1 32
# DEPOLARIZE2(0.1) 1 32
# CX 29 2
# DEPOLARIZE2(0.1) 29 2
# TICK
# CX 16 34
# DEPOLARIZE2(0.1) 16 34
# CX 49 12
# DEPOLARIZE2(0.1) 49 12
# CX 14 35
# DEPOLARIZE2(0.1) 14 35
# CX 46 17
# DEPOLARIZE2(0.1) 46 17
# CX 48 13
# DEPOLARIZE2(0.1) 48 13
# CX 11 30
# DEPOLARIZE2(0.1) 11 30
# CX 28 8
# DEPOLARIZE2(0.1) 28 8
# CX 0 44
# DEPOLARIZE2(0.1) 0 44
# CX 31 3
# DEPOLARIZE2(0.1) 31 3
# CX 2 36
# DEPOLARIZE2(0.1) 2 36
# CX 4 32
# DEPOLARIZE2(0.1) 4 32
# CX 29 1
# DEPOLARIZE2(0.1) 29 1
# TICK
# CX 11 39
# DEPOLARIZE2(0.1) 11 39
# CX 33 9
# DEPOLARIZE2(0.1) 33 9
# CX 49 10
# DEPOLARIZE2(0.1) 49 10
# CX 16 35
# DEPOLARIZE2(0.1) 16 35
# CX 48 12
# DEPOLARIZE2(0.1) 48 12
# CX 15 30
# DEPOLARIZE2(0.1) 15 30
# CX 31 1
# DEPOLARIZE2(0.1) 31 1
# CX 7 36
# DEPOLARIZE2(0.1) 7 36
# CX 0 32
# DEPOLARIZE2(0.1) 0 32
# CX 42 6
# DEPOLARIZE2(0.1) 42 6
# CX 29 5
# DEPOLARIZE2(0.1) 29 5
# CX 2 40
# DEPOLARIZE2(0.1) 2 40
# TICK
# CX 10 39
# DEPOLARIZE2(0.1) 10 39
# CX 33 15
# DEPOLARIZE2(0.1) 33 15
# CX 49 14
# DEPOLARIZE2(0.1) 49 14
# CX 17 35
# DEPOLARIZE2(0.1) 17 35
# CX 48 16
# DEPOLARIZE2(0.1) 48 16
# CX 12 30
# DEPOLARIZE2(0.1) 12 30
# CX 31 0
# DEPOLARIZE2(0.1) 31 0
# CX 1 36
# DEPOLARIZE2(0.1) 1 36
# CX 8 32
# DEPOLARIZE2(0.1) 8 32
# CX 42 7
# DEPOLARIZE2(0.1) 42 7
# CX 29 4
# DEPOLARIZE2(0.1) 29 4
# CX 5 40
# DEPOLARIZE2(0.1) 5 40
# TICK
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 42
# DEPOLARIZE1(0.1) 42
# H 29
# DEPOLARIZE1(0.1) 29
# TICK
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 28
# MRZ 28
# X_ERROR(0.1) 28
# X_ERROR(0.1) 44
# MRZ 44
# X_ERROR(0.1) 44
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# TICK
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 42
# DEPOLARIZE1(0.1) 42
# H 29
# DEPOLARIZE1(0.1) 29
# TICK
# CX 13 34
# DEPOLARIZE2(0.1) 13 34
# CX 49 11
# DEPOLARIZE2(0.1) 49 11
# CX 12 35
# DEPOLARIZE2(0.1) 12 35
# CX 46 14
# DEPOLARIZE2(0.1) 46 14
# CX 48 15
# DEPOLARIZE2(0.1) 48 15
# CX 9 30
# DEPOLARIZE2(0.1) 9 30
# CX 28 4
# DEPOLARIZE2(0.1) 28 4
# CX 3 44
# DEPOLARIZE2(0.1) 3 44
# CX 31 7
# DEPOLARIZE2(0.1) 31 7
# CX 6 36
# DEPOLARIZE2(0.1) 6 36
# CX 1 32
# DEPOLARIZE2(0.1) 1 32
# CX 29 2
# DEPOLARIZE2(0.1) 29 2
# TICK
# CX 16 34
# DEPOLARIZE2(0.1) 16 34
# CX 49 12
# DEPOLARIZE2(0.1) 49 12
# CX 14 35
# DEPOLARIZE2(0.1) 14 35
# CX 46 17
# DEPOLARIZE2(0.1) 46 17
# CX 48 13
# DEPOLARIZE2(0.1) 48 13
# CX 11 30
# DEPOLARIZE2(0.1) 11 30
# CX 28 8
# DEPOLARIZE2(0.1) 28 8
# CX 0 44
# DEPOLARIZE2(0.1) 0 44
# CX 31 3
# DEPOLARIZE2(0.1) 31 3
# CX 2 36
# DEPOLARIZE2(0.1) 2 36
# CX 4 32
# DEPOLARIZE2(0.1) 4 32
# CX 29 1
# DEPOLARIZE2(0.1) 29 1
# TICK
# CX 11 39
# DEPOLARIZE2(0.1) 11 39
# CX 33 9
# DEPOLARIZE2(0.1) 33 9
# CX 49 10
# DEPOLARIZE2(0.1) 49 10
# CX 16 35
# DEPOLARIZE2(0.1) 16 35
# CX 48 12
# DEPOLARIZE2(0.1) 48 12
# CX 15 30
# DEPOLARIZE2(0.1) 15 30
# CX 31 1
# DEPOLARIZE2(0.1) 31 1
# CX 7 36
# DEPOLARIZE2(0.1) 7 36
# CX 0 32
# DEPOLARIZE2(0.1) 0 32
# CX 42 6
# DEPOLARIZE2(0.1) 42 6
# CX 29 5
# DEPOLARIZE2(0.1) 29 5
# CX 2 40
# DEPOLARIZE2(0.1) 2 40
# TICK
# CX 10 39
# DEPOLARIZE2(0.1) 10 39
# CX 33 15
# DEPOLARIZE2(0.1) 33 15
# CX 49 14
# DEPOLARIZE2(0.1) 49 14
# CX 17 35
# DEPOLARIZE2(0.1) 17 35
# CX 48 16
# DEPOLARIZE2(0.1) 48 16
# CX 12 30
# DEPOLARIZE2(0.1) 12 30
# CX 31 0
# DEPOLARIZE2(0.1) 31 0
# CX 1 36
# DEPOLARIZE2(0.1) 1 36
# CX 8 32
# DEPOLARIZE2(0.1) 8 32
# CX 42 7
# DEPOLARIZE2(0.1) 42 7
# CX 29 4
# DEPOLARIZE2(0.1) 29 4
# CX 5 40
# DEPOLARIZE2(0.1) 5 40
# TICK
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 42
# DEPOLARIZE1(0.1) 42
# H 29
# DEPOLARIZE1(0.1) 29
# TICK
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 28
# MRZ 28
# X_ERROR(0.1) 28
# X_ERROR(0.1) 44
# MRZ 44
# X_ERROR(0.1) 44
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# TICK
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 42
# DEPOLARIZE1(0.1) 42
# H 29
# DEPOLARIZE1(0.1) 29
# TICK
# CX 13 34
# DEPOLARIZE2(0.1) 13 34
# CX 49 11
# DEPOLARIZE2(0.1) 49 11
# CX 12 35
# DEPOLARIZE2(0.1) 12 35
# CX 46 14
# DEPOLARIZE2(0.1) 46 14
# CX 48 15
# DEPOLARIZE2(0.1) 48 15
# CX 9 30
# DEPOLARIZE2(0.1) 9 30
# CX 28 4
# DEPOLARIZE2(0.1) 28 4
# CX 3 44
# DEPOLARIZE2(0.1) 3 44
# CX 31 7
# DEPOLARIZE2(0.1) 31 7
# CX 6 36
# DEPOLARIZE2(0.1) 6 36
# CX 1 32
# DEPOLARIZE2(0.1) 1 32
# CX 29 2
# DEPOLARIZE2(0.1) 29 2
# TICK
# CX 16 34
# DEPOLARIZE2(0.1) 16 34
# CX 49 12
# DEPOLARIZE2(0.1) 49 12
# CX 14 35
# DEPOLARIZE2(0.1) 14 35
# CX 46 17
# DEPOLARIZE2(0.1) 46 17
# CX 48 13
# DEPOLARIZE2(0.1) 48 13
# CX 11 30
# DEPOLARIZE2(0.1) 11 30
# CX 28 8
# DEPOLARIZE2(0.1) 28 8
# CX 0 44
# DEPOLARIZE2(0.1) 0 44
# CX 31 3
# DEPOLARIZE2(0.1) 31 3
# CX 2 36
# DEPOLARIZE2(0.1) 2 36
# CX 4 32
# DEPOLARIZE2(0.1) 4 32
# CX 29 1
# DEPOLARIZE2(0.1) 29 1
# TICK
# CX 11 39
# DEPOLARIZE2(0.1) 11 39
# CX 33 9
# DEPOLARIZE2(0.1) 33 9
# CX 49 10
# DEPOLARIZE2(0.1) 49 10
# CX 16 35
# DEPOLARIZE2(0.1) 16 35
# CX 48 12
# DEPOLARIZE2(0.1) 48 12
# CX 15 30
# DEPOLARIZE2(0.1) 15 30
# CX 31 1
# DEPOLARIZE2(0.1) 31 1
# CX 7 36
# DEPOLARIZE2(0.1) 7 36
# CX 0 32
# DEPOLARIZE2(0.1) 0 32
# CX 42 6
# DEPOLARIZE2(0.1) 42 6
# CX 29 5
# DEPOLARIZE2(0.1) 29 5
# CX 2 40
# DEPOLARIZE2(0.1) 2 40
# TICK
# CX 10 39
# DEPOLARIZE2(0.1) 10 39
# CX 33 15
# DEPOLARIZE2(0.1) 33 15
# CX 49 14
# DEPOLARIZE2(0.1) 49 14
# CX 17 35
# DEPOLARIZE2(0.1) 17 35
# CX 48 16
# DEPOLARIZE2(0.1) 48 16
# CX 12 30
# DEPOLARIZE2(0.1) 12 30
# CX 31 0
# DEPOLARIZE2(0.1) 31 0
# CX 1 36
# DEPOLARIZE2(0.1) 1 36
# CX 8 32
# DEPOLARIZE2(0.1) 8 32
# CX 42 7
# DEPOLARIZE2(0.1) 42 7
# CX 29 4
# DEPOLARIZE2(0.1) 29 4
# CX 5 40
# DEPOLARIZE2(0.1) 5 40
# TICK
# H 33
# DEPOLARIZE1(0.1) 33
# H 49
# DEPOLARIZE1(0.1) 49
# H 46
# DEPOLARIZE1(0.1) 46
# H 48
# DEPOLARIZE1(0.1) 48
# H 28
# DEPOLARIZE1(0.1) 28
# H 31
# DEPOLARIZE1(0.1) 31
# H 42
# DEPOLARIZE1(0.1) 42
# H 29
# DEPOLARIZE1(0.1) 29
# TICK
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 28
# MRZ 28
# X_ERROR(0.1) 28
# X_ERROR(0.1) 44
# MRZ 44
# X_ERROR(0.1) 44
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 15
# MZ 15
# X_ERROR(0.1) 14
# MZ 14
# X_ERROR(0.1) 16
# MZ 16
# X_ERROR(0.1) 10
# MZ 10
# X_ERROR(0.1) 13
# MZ 13
# X_ERROR(0.1) 17
# MZ 17
# X_ERROR(0.1) 9
# MZ 9
# X_ERROR(0.1) 11
# MZ 11
# X_ERROR(0.1) 12
# MZ 12
# TICK
# RZ 42 38 46 49 43 28 31
# X_ERROR(0.1) 42 38 46 49 43 28 31
# RZ 29
# X_ERROR(0.1) 29
# RZ 34
# X_ERROR(0.1) 34
# RZ 36
# X_ERROR(0.1) 36
# RZ 32
# X_ERROR(0.1) 32
# RZ 33
# X_ERROR(0.1) 33
# RZ 40
# X_ERROR(0.1) 40
# RZ 48
# X_ERROR(0.1) 48
# RZ 39
# X_ERROR(0.1) 39
# RZ 35
# X_ERROR(0.1) 35
# RZ 30
# X_ERROR(0.1) 30
# TICK
# RZ 42
# X_ERROR(0.1) 42
# RZ 31
# X_ERROR(0.1) 31
# RZ 46
# X_ERROR(0.1) 46
# RZ 49
# X_ERROR(0.1) 49
# TICK
# H 37
# DEPOLARIZE1(0.1) 37
# H 29
# DEPOLARIZE1(0.1) 29
# H 42
# DEPOLARIZE1(0.1) 42
# H 31
# DEPOLARIZE1(0.1) 31
# H 34
# DEPOLARIZE1(0.1) 34
# H 32
# DEPOLARIZE1(0.1) 32
# H 40
# DEPOLARIZE1(0.1) 40
# H 46
# DEPOLARIZE1(0.1) 46
# H 50
# DEPOLARIZE1(0.1) 50
# H 35
# DEPOLARIZE1(0.1) 35
# H 45
# DEPOLARIZE1(0.1) 45
# H 49
# DEPOLARIZE1(0.1) 49
# TICK
# CX 37 20
# DEPOLARIZE2(0.1) 37 20
# CX 29 23
# DEPOLARIZE2(0.1) 29 23
# CX 31 24
# DEPOLARIZE2(0.1) 31 24
# CX 34 4
# DEPOLARIZE2(0.1) 34 4
# CX 32 7
# DEPOLARIZE2(0.1) 32 7
# CX 6 33
# DEPOLARIZE2(0.1) 6 33
# CX 1 41
# DEPOLARIZE2(0.1) 1 41
# CX 40 2
# DEPOLARIZE2(0.1) 40 2
# CX 28 48
# DEPOLARIZE2(0.1) 28 48
# CX 46 43
# DEPOLARIZE2(0.1) 46 43
# CX 3 39
# DEPOLARIZE2(0.1) 3 39
# CX 19 30
# DEPOLARIZE2(0.1) 19 30
# CX 25 27
# DEPOLARIZE2(0.1) 25 27
# CX 45 21
# DEPOLARIZE2(0.1) 45 21
# CX 22 47
# DEPOLARIZE2(0.1) 22 47
# CX 49 38
# DEPOLARIZE2(0.1) 49 38
# TICK
# CX 37 19
# DEPOLARIZE2(0.1) 37 19
# CX 29 22
# DEPOLARIZE2(0.1) 29 22
# CX 31 28
# DEPOLARIZE2(0.1) 31 28
# CX 34 8
# DEPOLARIZE2(0.1) 34 8
# CX 32 3
# DEPOLARIZE2(0.1) 32 3
# CX 2 33
# DEPOLARIZE2(0.1) 2 33
# CX 4 41
# DEPOLARIZE2(0.1) 4 41
# CX 40 1
# DEPOLARIZE2(0.1) 40 1
# CX 38 48
# DEPOLARIZE2(0.1) 38 48
# CX 46 6
# DEPOLARIZE2(0.1) 46 6
# CX 0 39
# DEPOLARIZE2(0.1) 0 39
# CX 21 30
# DEPOLARIZE2(0.1) 21 30
# CX 20 27
# DEPOLARIZE2(0.1) 20 27
# CX 45 26
# DEPOLARIZE2(0.1) 45 26
# CX 24 47
# DEPOLARIZE2(0.1) 24 47
# CX 49 5
# DEPOLARIZE2(0.1) 49 5
# TICK
# CX 37 18
# DEPOLARIZE2(0.1) 37 18
# CX 29 19
# DEPOLARIZE2(0.1) 29 19
# CX 42 22
# DEPOLARIZE2(0.1) 42 22
# CX 31 26
# DEPOLARIZE2(0.1) 31 26
# CX 20 36
# DEPOLARIZE2(0.1) 20 36
# CX 32 1
# DEPOLARIZE2(0.1) 32 1
# CX 7 33
# DEPOLARIZE2(0.1) 7 33
# CX 0 41
# DEPOLARIZE2(0.1) 0 41
# CX 40 5
# DEPOLARIZE2(0.1) 40 5
# CX 2 48
# DEPOLARIZE2(0.1) 2 48
# CX 46 28
# DEPOLARIZE2(0.1) 46 28
# CX 50 25
# DEPOLARIZE2(0.1) 50 25
# CX 35 6
# DEPOLARIZE2(0.1) 35 6
# CX 24 30
# DEPOLARIZE2(0.1) 24 30
# CX 23 27
# DEPOLARIZE2(0.1) 23 27
# CX 43 47
# DEPOLARIZE2(0.1) 43 47
# TICK
# CX 37 21
# DEPOLARIZE2(0.1) 37 21
# CX 29 24
# DEPOLARIZE2(0.1) 29 24
# CX 42 43
# DEPOLARIZE2(0.1) 42 43
# CX 31 38
# DEPOLARIZE2(0.1) 31 38
# CX 18 36
# DEPOLARIZE2(0.1) 18 36
# CX 32 0
# DEPOLARIZE2(0.1) 32 0
# CX 1 33
# DEPOLARIZE2(0.1) 1 33
# CX 8 41
# DEPOLARIZE2(0.1) 8 41
# CX 40 4
# DEPOLARIZE2(0.1) 40 4
# CX 5 48
# DEPOLARIZE2(0.1) 5 48
# CX 46 2
# DEPOLARIZE2(0.1) 46 2
# CX 50 23
# DEPOLARIZE2(0.1) 50 23
# CX 35 7
# DEPOLARIZE2(0.1) 35 7
# CX 26 30
# DEPOLARIZE2(0.1) 26 30
# CX 19 27
# DEPOLARIZE2(0.1) 19 27
# CX 28 47
# DEPOLARIZE2(0.1) 28 47
# TICK
# H 37
# DEPOLARIZE1(0.1) 37
# H 29
# DEPOLARIZE1(0.1) 29
# H 42
# DEPOLARIZE1(0.1) 42
# H 31
# DEPOLARIZE1(0.1) 31
# H 34
# DEPOLARIZE1(0.1) 34
# H 32
# DEPOLARIZE1(0.1) 32
# H 40
# DEPOLARIZE1(0.1) 40
# H 46
# DEPOLARIZE1(0.1) 46
# H 50
# DEPOLARIZE1(0.1) 50
# H 35
# DEPOLARIZE1(0.1) 35
# H 45
# DEPOLARIZE1(0.1) 45
# H 49
# DEPOLARIZE1(0.1) 49
# TICK
# X_ERROR(0.1) 37
# MRZ 37
# X_ERROR(0.1) 37
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 41
# MRZ 41
# X_ERROR(0.1) 41
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 50
# MRZ 50
# X_ERROR(0.1) 50
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 27
# MRZ 27
# X_ERROR(0.1) 27
# X_ERROR(0.1) 45
# MRZ 45
# X_ERROR(0.1) 45
# X_ERROR(0.1) 47
# MRZ 47
# X_ERROR(0.1) 47
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# TICK
# H 37
# DEPOLARIZE1(0.1) 37
# H 29
# DEPOLARIZE1(0.1) 29
# H 42
# DEPOLARIZE1(0.1) 42
# H 31
# DEPOLARIZE1(0.1) 31
# H 34
# DEPOLARIZE1(0.1) 34
# H 32
# DEPOLARIZE1(0.1) 32
# H 40
# DEPOLARIZE1(0.1) 40
# H 46
# DEPOLARIZE1(0.1) 46
# H 50
# DEPOLARIZE1(0.1) 50
# H 35
# DEPOLARIZE1(0.1) 35
# H 45
# DEPOLARIZE1(0.1) 45
# H 49
# DEPOLARIZE1(0.1) 49
# TICK
# CX 37 20
# DEPOLARIZE2(0.1) 37 20
# CX 29 23
# DEPOLARIZE2(0.1) 29 23
# CX 31 24
# DEPOLARIZE2(0.1) 31 24
# CX 34 4
# DEPOLARIZE2(0.1) 34 4
# CX 32 7
# DEPOLARIZE2(0.1) 32 7
# CX 6 33
# DEPOLARIZE2(0.1) 6 33
# CX 1 41
# DEPOLARIZE2(0.1) 1 41
# CX 40 2
# DEPOLARIZE2(0.1) 40 2
# CX 28 48
# DEPOLARIZE2(0.1) 28 48
# CX 46 43
# DEPOLARIZE2(0.1) 46 43
# CX 3 39
# DEPOLARIZE2(0.1) 3 39
# CX 19 30
# DEPOLARIZE2(0.1) 19 30
# CX 25 27
# DEPOLARIZE2(0.1) 25 27
# CX 45 21
# DEPOLARIZE2(0.1) 45 21
# CX 22 47
# DEPOLARIZE2(0.1) 22 47
# CX 49 38
# DEPOLARIZE2(0.1) 49 38
# TICK
# CX 37 19
# DEPOLARIZE2(0.1) 37 19
# CX 29 22
# DEPOLARIZE2(0.1) 29 22
# CX 31 28
# DEPOLARIZE2(0.1) 31 28
# CX 34 8
# DEPOLARIZE2(0.1) 34 8
# CX 32 3
# DEPOLARIZE2(0.1) 32 3
# CX 2 33
# DEPOLARIZE2(0.1) 2 33
# CX 4 41
# DEPOLARIZE2(0.1) 4 41
# CX 40 1
# DEPOLARIZE2(0.1) 40 1
# CX 38 48
# DEPOLARIZE2(0.1) 38 48
# CX 46 6
# DEPOLARIZE2(0.1) 46 6
# CX 0 39
# DEPOLARIZE2(0.1) 0 39
# CX 21 30
# DEPOLARIZE2(0.1) 21 30
# CX 20 27
# DEPOLARIZE2(0.1) 20 27
# CX 45 26
# DEPOLARIZE2(0.1) 45 26
# CX 24 47
# DEPOLARIZE2(0.1) 24 47
# CX 49 5
# DEPOLARIZE2(0.1) 49 5
# TICK
# CX 37 18
# DEPOLARIZE2(0.1) 37 18
# CX 29 19
# DEPOLARIZE2(0.1) 29 19
# CX 42 22
# DEPOLARIZE2(0.1) 42 22
# CX 31 26
# DEPOLARIZE2(0.1) 31 26
# CX 20 36
# DEPOLARIZE2(0.1) 20 36
# CX 32 1
# DEPOLARIZE2(0.1) 32 1
# CX 7 33
# DEPOLARIZE2(0.1) 7 33
# CX 0 41
# DEPOLARIZE2(0.1) 0 41
# CX 40 5
# DEPOLARIZE2(0.1) 40 5
# CX 2 48
# DEPOLARIZE2(0.1) 2 48
# CX 46 28
# DEPOLARIZE2(0.1) 46 28
# CX 50 25
# DEPOLARIZE2(0.1) 50 25
# CX 35 6
# DEPOLARIZE2(0.1) 35 6
# CX 24 30
# DEPOLARIZE2(0.1) 24 30
# CX 23 27
# DEPOLARIZE2(0.1) 23 27
# CX 43 47
# DEPOLARIZE2(0.1) 43 47
# TICK
# CX 37 21
# DEPOLARIZE2(0.1) 37 21
# CX 29 24
# DEPOLARIZE2(0.1) 29 24
# CX 42 43
# DEPOLARIZE2(0.1) 42 43
# CX 31 38
# DEPOLARIZE2(0.1) 31 38
# CX 18 36
# DEPOLARIZE2(0.1) 18 36
# CX 32 0
# DEPOLARIZE2(0.1) 32 0
# CX 1 33
# DEPOLARIZE2(0.1) 1 33
# CX 8 41
# DEPOLARIZE2(0.1) 8 41
# CX 40 4
# DEPOLARIZE2(0.1) 40 4
# CX 5 48
# DEPOLARIZE2(0.1) 5 48
# CX 46 2
# DEPOLARIZE2(0.1) 46 2
# CX 50 23
# DEPOLARIZE2(0.1) 50 23
# CX 35 7
# DEPOLARIZE2(0.1) 35 7
# CX 26 30
# DEPOLARIZE2(0.1) 26 30
# CX 19 27
# DEPOLARIZE2(0.1) 19 27
# CX 28 47
# DEPOLARIZE2(0.1) 28 47
# TICK
# H 37
# DEPOLARIZE1(0.1) 37
# H 29
# DEPOLARIZE1(0.1) 29
# H 42
# DEPOLARIZE1(0.1) 42
# H 31
# DEPOLARIZE1(0.1) 31
# H 34
# DEPOLARIZE1(0.1) 34
# H 32
# DEPOLARIZE1(0.1) 32
# H 40
# DEPOLARIZE1(0.1) 40
# H 46
# DEPOLARIZE1(0.1) 46
# H 50
# DEPOLARIZE1(0.1) 50
# H 35
# DEPOLARIZE1(0.1) 35
# H 45
# DEPOLARIZE1(0.1) 45
# H 49
# DEPOLARIZE1(0.1) 49
# TICK
# X_ERROR(0.1) 37
# MRZ 37
# X_ERROR(0.1) 37
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 41
# MRZ 41
# X_ERROR(0.1) 41
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 50
# MRZ 50
# X_ERROR(0.1) 50
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 27
# MRZ 27
# X_ERROR(0.1) 27
# X_ERROR(0.1) 45
# MRZ 45
# X_ERROR(0.1) 45
# X_ERROR(0.1) 47
# MRZ 47
# X_ERROR(0.1) 47
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# TICK
# H 37
# DEPOLARIZE1(0.1) 37
# H 29
# DEPOLARIZE1(0.1) 29
# H 42
# DEPOLARIZE1(0.1) 42
# H 31
# DEPOLARIZE1(0.1) 31
# H 34
# DEPOLARIZE1(0.1) 34
# H 32
# DEPOLARIZE1(0.1) 32
# H 40
# DEPOLARIZE1(0.1) 40
# H 46
# DEPOLARIZE1(0.1) 46
# H 50
# DEPOLARIZE1(0.1) 50
# H 35
# DEPOLARIZE1(0.1) 35
# H 45
# DEPOLARIZE1(0.1) 45
# H 49
# DEPOLARIZE1(0.1) 49
# TICK
# CX 37 20
# DEPOLARIZE2(0.1) 37 20
# CX 29 23
# DEPOLARIZE2(0.1) 29 23
# CX 31 24
# DEPOLARIZE2(0.1) 31 24
# CX 34 4
# DEPOLARIZE2(0.1) 34 4
# CX 32 7
# DEPOLARIZE2(0.1) 32 7
# CX 6 33
# DEPOLARIZE2(0.1) 6 33
# CX 1 41
# DEPOLARIZE2(0.1) 1 41
# CX 40 2
# DEPOLARIZE2(0.1) 40 2
# CX 28 48
# DEPOLARIZE2(0.1) 28 48
# CX 46 43
# DEPOLARIZE2(0.1) 46 43
# CX 3 39
# DEPOLARIZE2(0.1) 3 39
# CX 19 30
# DEPOLARIZE2(0.1) 19 30
# CX 25 27
# DEPOLARIZE2(0.1) 25 27
# CX 45 21
# DEPOLARIZE2(0.1) 45 21
# CX 22 47
# DEPOLARIZE2(0.1) 22 47
# CX 49 38
# DEPOLARIZE2(0.1) 49 38
# TICK
# CX 37 19
# DEPOLARIZE2(0.1) 37 19
# CX 29 22
# DEPOLARIZE2(0.1) 29 22
# CX 31 28
# DEPOLARIZE2(0.1) 31 28
# CX 34 8
# DEPOLARIZE2(0.1) 34 8
# CX 32 3
# DEPOLARIZE2(0.1) 32 3
# CX 2 33
# DEPOLARIZE2(0.1) 2 33
# CX 4 41
# DEPOLARIZE2(0.1) 4 41
# CX 40 1
# DEPOLARIZE2(0.1) 40 1
# CX 38 48
# DEPOLARIZE2(0.1) 38 48
# CX 46 6
# DEPOLARIZE2(0.1) 46 6
# CX 0 39
# DEPOLARIZE2(0.1) 0 39
# CX 21 30
# DEPOLARIZE2(0.1) 21 30
# CX 20 27
# DEPOLARIZE2(0.1) 20 27
# CX 45 26
# DEPOLARIZE2(0.1) 45 26
# CX 24 47
# DEPOLARIZE2(0.1) 24 47
# CX 49 5
# DEPOLARIZE2(0.1) 49 5
# TICK
# CX 37 18
# DEPOLARIZE2(0.1) 37 18
# CX 29 19
# DEPOLARIZE2(0.1) 29 19
# CX 42 22
# DEPOLARIZE2(0.1) 42 22
# CX 31 26
# DEPOLARIZE2(0.1) 31 26
# CX 20 36
# DEPOLARIZE2(0.1) 20 36
# CX 32 1
# DEPOLARIZE2(0.1) 32 1
# CX 7 33
# DEPOLARIZE2(0.1) 7 33
# CX 0 41
# DEPOLARIZE2(0.1) 0 41
# CX 40 5
# DEPOLARIZE2(0.1) 40 5
# CX 2 48
# DEPOLARIZE2(0.1) 2 48
# CX 46 28
# DEPOLARIZE2(0.1) 46 28
# CX 50 25
# DEPOLARIZE2(0.1) 50 25
# CX 35 6
# DEPOLARIZE2(0.1) 35 6
# CX 24 30
# DEPOLARIZE2(0.1) 24 30
# CX 23 27
# DEPOLARIZE2(0.1) 23 27
# CX 43 47
# DEPOLARIZE2(0.1) 43 47
# TICK
# CX 37 21
# DEPOLARIZE2(0.1) 37 21
# CX 29 24
# DEPOLARIZE2(0.1) 29 24
# CX 42 43
# DEPOLARIZE2(0.1) 42 43
# CX 31 38
# DEPOLARIZE2(0.1) 31 38
# CX 18 36
# DEPOLARIZE2(0.1) 18 36
# CX 32 0
# DEPOLARIZE2(0.1) 32 0
# CX 1 33
# DEPOLARIZE2(0.1) 1 33
# CX 8 41
# DEPOLARIZE2(0.1) 8 41
# CX 40 4
# DEPOLARIZE2(0.1) 40 4
# CX 5 48
# DEPOLARIZE2(0.1) 5 48
# CX 46 2
# DEPOLARIZE2(0.1) 46 2
# CX 50 23
# DEPOLARIZE2(0.1) 50 23
# CX 35 7
# DEPOLARIZE2(0.1) 35 7
# CX 26 30
# DEPOLARIZE2(0.1) 26 30
# CX 19 27
# DEPOLARIZE2(0.1) 19 27
# CX 28 47
# DEPOLARIZE2(0.1) 28 47
# TICK
# H 37
# DEPOLARIZE1(0.1) 37
# H 29
# DEPOLARIZE1(0.1) 29
# H 42
# DEPOLARIZE1(0.1) 42
# H 31
# DEPOLARIZE1(0.1) 31
# H 34
# DEPOLARIZE1(0.1) 34
# H 32
# DEPOLARIZE1(0.1) 32
# H 40
# DEPOLARIZE1(0.1) 40
# H 46
# DEPOLARIZE1(0.1) 46
# H 50
# DEPOLARIZE1(0.1) 50
# H 35
# DEPOLARIZE1(0.1) 35
# H 45
# DEPOLARIZE1(0.1) 45
# H 49
# DEPOLARIZE1(0.1) 49
# TICK
# X_ERROR(0.1) 37
# MRZ 37
# X_ERROR(0.1) 37
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 42
# MRZ 42
# X_ERROR(0.1) 42
# X_ERROR(0.1) 31
# MRZ 31
# X_ERROR(0.1) 31
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 41
# MRZ 41
# X_ERROR(0.1) 41
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 46
# MRZ 46
# X_ERROR(0.1) 46
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 50
# MRZ 50
# X_ERROR(0.1) 50
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 27
# MRZ 27
# X_ERROR(0.1) 27
# X_ERROR(0.1) 45
# MRZ 45
# X_ERROR(0.1) 45
# X_ERROR(0.1) 47
# MRZ 47
# X_ERROR(0.1) 47
# X_ERROR(0.1) 49
# MRZ 49
# X_ERROR(0.1) 49
# X_ERROR(0.1) 38
# MZ 38
# X_ERROR(0.1) 28
# MZ 28
# X_ERROR(0.1) 43
# MZ 43
# TICK
# RZ 34
# X_ERROR(0.1) 34
# RZ 39
# X_ERROR(0.1) 39
# RZ 32
# X_ERROR(0.1) 32
# RZ 33
# X_ERROR(0.1) 33
# RZ 41
# X_ERROR(0.1) 41
# RZ 35
# X_ERROR(0.1) 35
# RZ 40
# X_ERROR(0.1) 40
# RZ 48
# X_ERROR(0.1) 48
# RZ 36
# X_ERROR(0.1) 36
# RZ 50
# X_ERROR(0.1) 50
# RZ 37
# X_ERROR(0.1) 37
# RZ 45
# X_ERROR(0.1) 45
# RZ 29
# X_ERROR(0.1) 29
# RZ 47
# X_ERROR(0.1) 47
# RZ 30
# X_ERROR(0.1) 30
# RZ 27
# X_ERROR(0.1) 27
# TICK
# H 34
# DEPOLARIZE1(0.1) 34
# H 32
# DEPOLARIZE1(0.1) 32
# H 35
# DEPOLARIZE1(0.1) 35
# H 40
# DEPOLARIZE1(0.1) 40
# H 50
# DEPOLARIZE1(0.1) 50
# H 37
# DEPOLARIZE1(0.1) 37
# H 45
# DEPOLARIZE1(0.1) 45
# H 29
# DEPOLARIZE1(0.1) 29
# TICK
# CX 34 4
# DEPOLARIZE2(0.1) 34 4
# CX 3 39
# DEPOLARIZE2(0.1) 3 39
# CX 32 7
# DEPOLARIZE2(0.1) 32 7
# CX 6 33
# DEPOLARIZE2(0.1) 6 33
# CX 1 41
# DEPOLARIZE2(0.1) 1 41
# CX 40 2
# DEPOLARIZE2(0.1) 40 2
# CX 37 20
# DEPOLARIZE2(0.1) 37 20
# CX 45 21
# DEPOLARIZE2(0.1) 45 21
# CX 29 23
# DEPOLARIZE2(0.1) 29 23
# CX 22 47
# DEPOLARIZE2(0.1) 22 47
# CX 19 30
# DEPOLARIZE2(0.1) 19 30
# CX 25 27
# DEPOLARIZE2(0.1) 25 27
# TICK
# CX 34 8
# DEPOLARIZE2(0.1) 34 8
# CX 0 39
# DEPOLARIZE2(0.1) 0 39
# CX 32 3
# DEPOLARIZE2(0.1) 32 3
# CX 2 33
# DEPOLARIZE2(0.1) 2 33
# CX 4 41
# DEPOLARIZE2(0.1) 4 41
# CX 40 1
# DEPOLARIZE2(0.1) 40 1
# CX 37 19
# DEPOLARIZE2(0.1) 37 19
# CX 45 26
# DEPOLARIZE2(0.1) 45 26
# CX 29 22
# DEPOLARIZE2(0.1) 29 22
# CX 24 47
# DEPOLARIZE2(0.1) 24 47
# CX 21 30
# DEPOLARIZE2(0.1) 21 30
# CX 20 27
# DEPOLARIZE2(0.1) 20 27
# TICK
# CX 32 1
# DEPOLARIZE2(0.1) 32 1
# CX 7 33
# DEPOLARIZE2(0.1) 7 33
# CX 0 41
# DEPOLARIZE2(0.1) 0 41
# CX 35 6
# DEPOLARIZE2(0.1) 35 6
# CX 40 5
# DEPOLARIZE2(0.1) 40 5
# CX 2 48
# DEPOLARIZE2(0.1) 2 48
# CX 20 36
# DEPOLARIZE2(0.1) 20 36
# CX 50 25
# DEPOLARIZE2(0.1) 50 25
# CX 37 18
# DEPOLARIZE2(0.1) 37 18
# CX 29 19
# DEPOLARIZE2(0.1) 29 19
# CX 24 30
# DEPOLARIZE2(0.1) 24 30
# CX 23 27
# DEPOLARIZE2(0.1) 23 27
# TICK
# CX 32 0
# DEPOLARIZE2(0.1) 32 0
# CX 1 33
# DEPOLARIZE2(0.1) 1 33
# CX 8 41
# DEPOLARIZE2(0.1) 8 41
# CX 35 7
# DEPOLARIZE2(0.1) 35 7
# CX 40 4
# DEPOLARIZE2(0.1) 40 4
# CX 5 48
# DEPOLARIZE2(0.1) 5 48
# CX 18 36
# DEPOLARIZE2(0.1) 18 36
# CX 50 23
# DEPOLARIZE2(0.1) 50 23
# CX 37 21
# DEPOLARIZE2(0.1) 37 21
# CX 29 24
# DEPOLARIZE2(0.1) 29 24
# CX 26 30
# DEPOLARIZE2(0.1) 26 30
# CX 19 27
# DEPOLARIZE2(0.1) 19 27
# TICK
# H 34
# DEPOLARIZE1(0.1) 34
# H 32
# DEPOLARIZE1(0.1) 32
# H 35
# DEPOLARIZE1(0.1) 35
# H 40
# DEPOLARIZE1(0.1) 40
# H 50
# DEPOLARIZE1(0.1) 50
# H 37
# DEPOLARIZE1(0.1) 37
# H 45
# DEPOLARIZE1(0.1) 45
# H 29
# DEPOLARIZE1(0.1) 29
# TICK
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 41
# MRZ 41
# X_ERROR(0.1) 41
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 50
# MRZ 50
# X_ERROR(0.1) 50
# X_ERROR(0.1) 37
# MRZ 37
# X_ERROR(0.1) 37
# X_ERROR(0.1) 45
# MRZ 45
# X_ERROR(0.1) 45
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 47
# MRZ 47
# X_ERROR(0.1) 47
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 27
# MRZ 27
# X_ERROR(0.1) 27
# TICK
# H 34
# DEPOLARIZE1(0.1) 34
# H 32
# DEPOLARIZE1(0.1) 32
# H 35
# DEPOLARIZE1(0.1) 35
# H 40
# DEPOLARIZE1(0.1) 40
# H 50
# DEPOLARIZE1(0.1) 50
# H 37
# DEPOLARIZE1(0.1) 37
# H 45
# DEPOLARIZE1(0.1) 45
# H 29
# DEPOLARIZE1(0.1) 29
# TICK
# CX 34 4
# DEPOLARIZE2(0.1) 34 4
# CX 3 39
# DEPOLARIZE2(0.1) 3 39
# CX 32 7
# DEPOLARIZE2(0.1) 32 7
# CX 6 33
# DEPOLARIZE2(0.1) 6 33
# CX 1 41
# DEPOLARIZE2(0.1) 1 41
# CX 40 2
# DEPOLARIZE2(0.1) 40 2
# CX 37 20
# DEPOLARIZE2(0.1) 37 20
# CX 45 21
# DEPOLARIZE2(0.1) 45 21
# CX 29 23
# DEPOLARIZE2(0.1) 29 23
# CX 22 47
# DEPOLARIZE2(0.1) 22 47
# CX 19 30
# DEPOLARIZE2(0.1) 19 30
# CX 25 27
# DEPOLARIZE2(0.1) 25 27
# TICK
# CX 34 8
# DEPOLARIZE2(0.1) 34 8
# CX 0 39
# DEPOLARIZE2(0.1) 0 39
# CX 32 3
# DEPOLARIZE2(0.1) 32 3
# CX 2 33
# DEPOLARIZE2(0.1) 2 33
# CX 4 41
# DEPOLARIZE2(0.1) 4 41
# CX 40 1
# DEPOLARIZE2(0.1) 40 1
# CX 37 19
# DEPOLARIZE2(0.1) 37 19
# CX 45 26
# DEPOLARIZE2(0.1) 45 26
# CX 29 22
# DEPOLARIZE2(0.1) 29 22
# CX 24 47
# DEPOLARIZE2(0.1) 24 47
# CX 21 30
# DEPOLARIZE2(0.1) 21 30
# CX 20 27
# DEPOLARIZE2(0.1) 20 27
# TICK
# CX 32 1
# DEPOLARIZE2(0.1) 32 1
# CX 7 33
# DEPOLARIZE2(0.1) 7 33
# CX 0 41
# DEPOLARIZE2(0.1) 0 41
# CX 35 6
# DEPOLARIZE2(0.1) 35 6
# CX 40 5
# DEPOLARIZE2(0.1) 40 5
# CX 2 48
# DEPOLARIZE2(0.1) 2 48
# CX 20 36
# DEPOLARIZE2(0.1) 20 36
# CX 50 25
# DEPOLARIZE2(0.1) 50 25
# CX 37 18
# DEPOLARIZE2(0.1) 37 18
# CX 29 19
# DEPOLARIZE2(0.1) 29 19
# CX 24 30
# DEPOLARIZE2(0.1) 24 30
# CX 23 27
# DEPOLARIZE2(0.1) 23 27
# TICK
# CX 32 0
# DEPOLARIZE2(0.1) 32 0
# CX 1 33
# DEPOLARIZE2(0.1) 1 33
# CX 8 41
# DEPOLARIZE2(0.1) 8 41
# CX 35 7
# DEPOLARIZE2(0.1) 35 7
# CX 40 4
# DEPOLARIZE2(0.1) 40 4
# CX 5 48
# DEPOLARIZE2(0.1) 5 48
# CX 18 36
# DEPOLARIZE2(0.1) 18 36
# CX 50 23
# DEPOLARIZE2(0.1) 50 23
# CX 37 21
# DEPOLARIZE2(0.1) 37 21
# CX 29 24
# DEPOLARIZE2(0.1) 29 24
# CX 26 30
# DEPOLARIZE2(0.1) 26 30
# CX 19 27
# DEPOLARIZE2(0.1) 19 27
# TICK
# H 34
# DEPOLARIZE1(0.1) 34
# H 32
# DEPOLARIZE1(0.1) 32
# H 35
# DEPOLARIZE1(0.1) 35
# H 40
# DEPOLARIZE1(0.1) 40
# H 50
# DEPOLARIZE1(0.1) 50
# H 37
# DEPOLARIZE1(0.1) 37
# H 45
# DEPOLARIZE1(0.1) 45
# H 29
# DEPOLARIZE1(0.1) 29
# TICK
# X_ERROR(0.1) 34
# MRZ 34
# X_ERROR(0.1) 34
# X_ERROR(0.1) 39
# MRZ 39
# X_ERROR(0.1) 39
# X_ERROR(0.1) 32
# MRZ 32
# X_ERROR(0.1) 32
# X_ERROR(0.1) 33
# MRZ 33
# X_ERROR(0.1) 33
# X_ERROR(0.1) 41
# MRZ 41
# X_ERROR(0.1) 41
# X_ERROR(0.1) 35
# MRZ 35
# X_ERROR(0.1) 35
# X_ERROR(0.1) 40
# MRZ 40
# X_ERROR(0.1) 40
# X_ERROR(0.1) 48
# MRZ 48
# X_ERROR(0.1) 48
# X_ERROR(0.1) 36
# MRZ 36
# X_ERROR(0.1) 36
# X_ERROR(0.1) 50
# MRZ 50
# X_ERROR(0.1) 50
# X_ERROR(0.1) 37
# MRZ 37
# X_ERROR(0.1) 37
# X_ERROR(0.1) 45
# MRZ 45
# X_ERROR(0.1) 45
# X_ERROR(0.1) 29
# MRZ 29
# X_ERROR(0.1) 29
# X_ERROR(0.1) 47
# MRZ 47
# X_ERROR(0.1) 47
# X_ERROR(0.1) 30
# MRZ 30
# X_ERROR(0.1) 30
# X_ERROR(0.1) 27
# MRZ 27
# X_ERROR(0.1) 27
# TICK
# H 34
# DEPOLARIZE1(0.1) 34
# H 32
# DEPOLARIZE1(0.1) 32
# H 35
# DEPOLARIZE1(0.1) 35
# H 40
# DEPOLARIZE1(0.1) 40
# H 50
# DEPOLARIZE1(0.1) 50
# H 37
# DEPOLARIZE1(0.1) 37
# H 45
# DEPOLARIZE1(0.1) 45
# H 29
# DEPOLARIZE1(0.1) 29
# TICK
# CX 34 4
# DEPOLARIZE2(0.1) 34 4
# CX 3 39
# DEPOLARIZE2(0.1) 3 39
# CX 32 7
# DEPOLARIZE2(0.1) 32 7
# CX 6 33
# DEPOLARIZE2(0.1) 6 33
# CX 1 41
# DEPOLARIZE2(0.1) 1 41
# CX 40 2
# DEPOLARIZE2(0.1) 40 2
# CX 37 20
# DEPOLARIZE2(0.1) 37 20
# CX 45 21
# DEPOLARIZE2(0.1) 45 21
# CX 29 23
# DEPOLARIZE2(0.1) 29 23
# CX 22 47
# DEPOLARIZE2(0.1) 22 47
# CX 19 30
# DEPOLARIZE2(0.1) 19 30
# CX 25 27
# DEPOLARIZE2(0.1) 25 27
# TICK
# CX 34 8
# DEPOLARIZE2(0.1) 34 8
# CX 0 39
# DEPOLARIZE2(0.1) 0 39
# CX 32 3
# DEPOLARIZE2(0.1) 32 3
# CX 2 33
# DEPOLARIZE2(0.1) 2 33
# CX 4 41
# DEPOLARIZE2(0.1) 4 41
# CX 40 1
# DEPOLARIZE2(0.1) 40 1
# CX 37 19
# DEPOLARIZE2(0.1) 37 19
# CX 45 26
# DEPOLARIZE2(0.1) 45 26
# CX 29 22
# DEPOLARIZE2(0.1) 29 22
# CX 24 47
# DEPOLARIZE2(0.1) 24 47
# CX 21 30
# DEPOLARIZE2(0.1) 21 30
# CX 20 27
# DEPOLARIZE2(0.1) 20 27
# TICK
# CX 32 1
# DEPOLARIZE2(0.1) 32 1
# CX 7 33
# DEPOLARIZE2(0.1) 7 33
# CX 0 41
# DEPOLARIZE2(0.1) 0 41
# CX 35 6
# DEPOLARIZE2(0.1) 35 6
# CX 40 5
# DEPOLARIZE2(0.1) 40 5
# CX 2 48
# DEPOLARIZE2(0.1) 2 48
# CX 20 36
# DEPOLARIZE2(0.1) 20 36
# CX 50 25
# ...
# DETECTOR rec[-238] rec[-218] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_z_3_rsc1_r0_1
# DETECTOR rec[-218] rec[-198] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_z_3_rsc1_r1_2
# DETECTOR rec[-237] rec[-260] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_x_2_rsc2_r0
# DETECTOR rec[-237] rec[-217] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_x_2_rsc2_r0_1
# DETECTOR rec[-217] rec[-197] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_x_2_rsc2_r1_2
# DETECTOR rec[-236] rec[-259] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_x_0_rsc2_r0
# DETECTOR rec[-236] rec[-216] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_x_0_rsc2_r0_1
# DETECTOR rec[-216] rec[-196] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_x_0_rsc2_r1_2
# DETECTOR rec[-235] rec[-265] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_z_3_rsc2_r0
# DETECTOR rec[-235] rec[-215] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_z_3_rsc2_r0_1
# DETECTOR rec[-215] rec[-195] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_z_3_rsc2_r1_2
# DETECTOR rec[-234] rec[-272] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_z_2_rsc1_r0
# DETECTOR rec[-234] rec[-214] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_z_2_rsc1_r0_1
# DETECTOR rec[-214] rec[-194] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_z_2_rsc1_r1_2
# DETECTOR rec[-233] rec[-268] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_x_3_rsc1_r0
# DETECTOR rec[-233] rec[-213] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_x_3_rsc1_r0_1
# DETECTOR rec[-213] rec[-193] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_x_3_rsc1_r1_2
# DETECTOR rec[-232] rec[-212] # rsc_surgery_merged_syndrome_MZZ_ac_det_anc_check_0_r0_1
# DETECTOR rec[-212] rec[-192] # rsc_surgery_merged_syndrome_MZZ_ac_det_anc_check_0_r1_2
# DETECTOR rec[-231] rec[-264] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_z_2_rsc2_r0
# DETECTOR rec[-231] rec[-211] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_z_2_rsc2_r0_1
# DETECTOR rec[-211] rec[-191] # rsc_surgery_merged_syndrome_MZZ_ac_det_c_z_2_rsc2_r1_2
# DETECTOR rec[-230] rec[-210] # rsc_surgery_merged_syndrome_MZZ_ac_det_anc_check_2_r0_1
# DETECTOR rec[-210] rec[-190] # rsc_surgery_merged_syndrome_MZZ_ac_det_anc_check_2_r1_2
# DETECTOR rec[-186] rec[-195] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_3_rsc2_r0
# DETECTOR rec[-186] rec[-170] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_3_rsc2_r0_1
# DETECTOR rec[-170] rec[-154] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_3_rsc2_r1_2
# DETECTOR rec[-185] rec[-191] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_2_rsc2_r0
# DETECTOR rec[-185] rec[-169] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_2_rsc2_r0_1
# DETECTOR rec[-169] rec[-153] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_2_rsc2_r1_2
# DETECTOR rec[-184] rec[-202] rec[-188] rec[-187] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_3_rsc2_r0
# DETECTOR rec[-184] rec[-168] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_3_rsc2_r0_1
# DETECTOR rec[-168] rec[-152] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_3_rsc2_r1_2
# DETECTOR rec[-183] rec[-200] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_1_rsc2_r0
# DETECTOR rec[-183] rec[-167] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_1_rsc2_r0_1
# DETECTOR rec[-167] rec[-151] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_1_rsc2_r1_2
# DETECTOR rec[-182] rec[-208] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_1_rsc2_r0
# DETECTOR rec[-182] rec[-166] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_1_rsc2_r0_1
# DETECTOR rec[-166] rec[-150] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_1_rsc2_r1_2
# DETECTOR rec[-181] rec[-197] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_2_rsc2_r0
# DETECTOR rec[-181] rec[-165] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_2_rsc2_r0_1
# DETECTOR rec[-165] rec[-149] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_2_rsc2_r1_2
# DETECTOR rec[-180] rec[-196] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_0_rsc2_r0
# DETECTOR rec[-180] rec[-164] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_0_rsc2_r0_1
# DETECTOR rec[-164] rec[-148] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_0_rsc2_r1_2
# DETECTOR rec[-179] rec[-207] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_0_rsc2_r0
# DETECTOR rec[-179] rec[-163] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_0_rsc2_r0_1
# DETECTOR rec[-163] rec[-147] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_0_rsc2_r1_2
# DETECTOR rec[-178] rec[-206] rec[-189] rec[-188] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_2_rsc1_r0
# DETECTOR rec[-178] rec[-162] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_2_rsc1_r0_1
# DETECTOR rec[-162] rec[-146] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_2_rsc1_r1_2
# DETECTOR rec[-177] rec[-194] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_2_rsc1_r0
# DETECTOR rec[-177] rec[-161] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_2_rsc1_r0_1
# DETECTOR rec[-161] rec[-145] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_2_rsc1_r1_2
# DETECTOR rec[-176] rec[-205] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_0_rsc1_r0
# DETECTOR rec[-176] rec[-160] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_0_rsc1_r0_1
# DETECTOR rec[-160] rec[-144] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_0_rsc1_r1_2
# DETECTOR rec[-175] rec[-204] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_0_rsc1_r0
# DETECTOR rec[-175] rec[-159] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_0_rsc1_r0_1
# DETECTOR rec[-159] rec[-143] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_0_rsc1_r1_2
# DETECTOR rec[-174] rec[-203] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_1_rsc1_r0
# DETECTOR rec[-174] rec[-158] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_1_rsc1_r0_1
# DETECTOR rec[-158] rec[-142] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_1_rsc1_r1_2
# DETECTOR rec[-173] rec[-193] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_3_rsc1_r0
# DETECTOR rec[-173] rec[-157] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_3_rsc1_r0_1
# DETECTOR rec[-157] rec[-141] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_3_rsc1_r1_2
# DETECTOR rec[-172] rec[-199] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_1_rsc1_r0
# DETECTOR rec[-172] rec[-156] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_1_rsc1_r0_1
# DETECTOR rec[-156] rec[-140] # rsc_surgery_split_syndrome_MZZ_ac_det_c_x_1_rsc1_r1_2
# DETECTOR rec[-171] rec[-198] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_3_rsc1_r0
# DETECTOR rec[-171] rec[-155] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_3_rsc1_r0_1
# DETECTOR rec[-155] rec[-139] # rsc_surgery_split_syndrome_MZZ_ac_det_c_z_3_rsc1_r1_2
# DETECTOR rec[-129] rec[-255] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_1_rsc3_r0
# DETECTOR rec[-129] rec[-109] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_1_rsc3_r0_1
# DETECTOR rec[-109] rec[-89] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_1_rsc3_r1_2
# DETECTOR rec[-128] rec[-253] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_0_rsc3_r0
# DETECTOR rec[-128] rec[-108] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_0_rsc3_r0_1
# DETECTOR rec[-108] rec[-88] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_0_rsc3_r1_2
# DETECTOR rec[-127] rec[-107] # rsc_surgery_merged_syndrome_MXX_ct_det_anc_check_0_r0_1
# DETECTOR rec[-107] rec[-87] # rsc_surgery_merged_syndrome_MXX_ct_det_anc_check_0_r1_2
# DETECTOR rec[-126] rec[-106] # rsc_surgery_merged_syndrome_MXX_ct_det_anc_check_4_r0_1
# DETECTOR rec[-106] rec[-86] # rsc_surgery_merged_syndrome_MXX_ct_det_anc_check_4_r1_2
# DETECTOR rec[-125] rec[-146] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_2_rsc1_r0
# DETECTOR rec[-125] rec[-105] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_2_rsc1_r0_1
# DETECTOR rec[-105] rec[-85] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_2_rsc1_r1_2
# DETECTOR rec[-124] rec[-257] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_3_rsc3_r0
# DETECTOR rec[-124] rec[-104] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_3_rsc3_r0_1
# DETECTOR rec[-104] rec[-84] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_3_rsc3_r1_2
# DETECTOR rec[-123] rec[-144] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_0_rsc1_r0
# DETECTOR rec[-123] rec[-103] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_0_rsc1_r0_1
# DETECTOR rec[-103] rec[-83] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_0_rsc1_r1_2
# DETECTOR rec[-122] rec[-143] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_0_rsc1_r0
# DETECTOR rec[-122] rec[-102] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_0_rsc1_r0_1
# DETECTOR rec[-102] rec[-82] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_0_rsc1_r1_2
# DETECTOR rec[-121] rec[-142] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_1_rsc1_r0
# DETECTOR rec[-121] rec[-101] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_1_rsc1_r0_1
# DETECTOR rec[-101] rec[-81] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_1_rsc1_r1_2
# DETECTOR rec[-120] rec[-140] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_1_rsc1_r0
# DETECTOR rec[-120] rec[-100] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_1_rsc1_r0_1
# DETECTOR rec[-100] rec[-80] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_1_rsc1_r1_2
# DETECTOR rec[-119] rec[-139] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_3_rsc1_r0
# DETECTOR rec[-119] rec[-99] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_3_rsc1_r0_1
# DETECTOR rec[-99] rec[-79] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_3_rsc1_r1_2
# DETECTOR rec[-118] rec[-98] # rsc_surgery_merged_syndrome_MXX_ct_det_anc_check_2_r0_1
# DETECTOR rec[-98] rec[-78] # rsc_surgery_merged_syndrome_MXX_ct_det_anc_check_2_r1_2
# DETECTOR rec[-117] rec[-145] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_2_rsc1_r0
# DETECTOR rec[-117] rec[-97] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_2_rsc1_r0_1
# DETECTOR rec[-97] rec[-77] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_2_rsc1_r1_2
# DETECTOR rec[-116] rec[-256] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_3_rsc3_r0
# DETECTOR rec[-116] rec[-96] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_3_rsc3_r0_1
# DETECTOR rec[-96] rec[-76] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_3_rsc3_r1_2
# DETECTOR rec[-115] rec[-141] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_3_rsc1_r0
# DETECTOR rec[-115] rec[-95] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_3_rsc1_r0_1
# DETECTOR rec[-95] rec[-75] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_3_rsc1_r1_2
# DETECTOR rec[-114] rec[-251] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_1_rsc3_r0
# DETECTOR rec[-114] rec[-94] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_1_rsc3_r0_1
# DETECTOR rec[-94] rec[-74] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_1_rsc3_r1_2
# DETECTOR rec[-113] rec[-250] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_0_rsc3_r0
# DETECTOR rec[-113] rec[-93] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_0_rsc3_r0_1
# DETECTOR rec[-93] rec[-73] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_0_rsc3_r1_2
# DETECTOR rec[-112] rec[-254] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_2_rsc3_r0
# DETECTOR rec[-112] rec[-92] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_2_rsc3_r0_1
# DETECTOR rec[-92] rec[-72] # rsc_surgery_merged_syndrome_MXX_ct_det_c_x_2_rsc3_r1_2
# DETECTOR rec[-111] rec[-252] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_2_rsc3_r0
# DETECTOR rec[-111] rec[-91] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_2_rsc3_r0_1
# DETECTOR rec[-91] rec[-71] # rsc_surgery_merged_syndrome_MXX_ct_det_c_z_2_rsc3_r1_2
# DETECTOR rec[-110] rec[-90] # rsc_surgery_merged_syndrome_MXX_ct_det_anc_check_6_r0_1
# DETECTOR rec[-90] rec[-70] # rsc_surgery_merged_syndrome_MXX_ct_det_anc_check_6_r1_2
# DETECTOR rec[-66] rec[-85] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_2_rsc1_r0
# DETECTOR rec[-66] rec[-50] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_2_rsc1_r0_1
# DETECTOR rec[-50] rec[-34] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_2_rsc1_r1_2
# DETECTOR rec[-65] rec[-77] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_2_rsc1_r0
# DETECTOR rec[-65] rec[-49] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_2_rsc1_r0_1
# DETECTOR rec[-49] rec[-33] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_2_rsc1_r1_2
# DETECTOR rec[-64] rec[-83] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_0_rsc1_r0
# DETECTOR rec[-64] rec[-48] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_0_rsc1_r0_1
# DETECTOR rec[-48] rec[-32] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_0_rsc1_r1_2
# DETECTOR rec[-63] rec[-82] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_0_rsc1_r0
# DETECTOR rec[-63] rec[-47] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_0_rsc1_r0_1
# DETECTOR rec[-47] rec[-31] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_0_rsc1_r1_2
# DETECTOR rec[-62] rec[-81] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_1_rsc1_r0
# DETECTOR rec[-62] rec[-46] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_1_rsc1_r0_1
# DETECTOR rec[-46] rec[-30] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_1_rsc1_r1_2
# DETECTOR rec[-61] rec[-75] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_3_rsc1_r0
# DETECTOR rec[-61] rec[-45] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_3_rsc1_r0_1
# DETECTOR rec[-45] rec[-29] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_3_rsc1_r1_2
# DETECTOR rec[-60] rec[-80] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_1_rsc1_r0
# DETECTOR rec[-60] rec[-44] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_1_rsc1_r0_1
# DETECTOR rec[-44] rec[-28] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_1_rsc1_r1_2
# DETECTOR rec[-59] rec[-79] rec[-69] rec[-68] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_3_rsc1_r0
# DETECTOR rec[-59] rec[-43] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_3_rsc1_r0_1
# DETECTOR rec[-43] rec[-27] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_3_rsc1_r1_2
# DETECTOR rec[-58] rec[-84] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_3_rsc3_r0
# DETECTOR rec[-58] rec[-42] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_3_rsc3_r0_1
# DETECTOR rec[-42] rec[-26] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_3_rsc3_r1_2
# DETECTOR rec[-57] rec[-76] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_3_rsc3_r0
# DETECTOR rec[-57] rec[-41] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_3_rsc3_r0_1
# DETECTOR rec[-41] rec[-25] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_3_rsc3_r1_2
# DETECTOR rec[-56] rec[-89] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_1_rsc3_r0
# DETECTOR rec[-56] rec[-40] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_1_rsc3_r0_1
# DETECTOR rec[-40] rec[-24] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_1_rsc3_r1_2
# DETECTOR rec[-55] rec[-72] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_2_rsc3_r0
# DETECTOR rec[-55] rec[-39] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_2_rsc3_r0_1
# DETECTOR rec[-39] rec[-23] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_2_rsc3_r1_2
# DETECTOR rec[-54] rec[-88] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_0_rsc3_r0
# DETECTOR rec[-54] rec[-38] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_0_rsc3_r0_1
# DETECTOR rec[-38] rec[-22] # rsc_surgery_split_syndrome_MXX_ct_det_c_x_0_rsc3_r1_2
# DETECTOR rec[-53] rec[-71] rec[-67] rec[-68] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_2_rsc3_r0
# DETECTOR rec[-53] rec[-37] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_2_rsc3_r0_1
# DETECTOR rec[-37] rec[-21] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_2_rsc3_r1_2
# DETECTOR rec[-52] rec[-74] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_1_rsc3_r0
# DETECTOR rec[-52] rec[-36] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_1_rsc3_r0_1
# DETECTOR rec[-36] rec[-20] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_1_rsc3_r1_2
# DETECTOR rec[-51] rec[-73] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_0_rsc3_r0
# DETECTOR rec[-51] rec[-35] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_0_rsc3_r0_1
# DETECTOR rec[-35] rec[-19] # rsc_surgery_split_syndrome_MXX_ct_det_c_z_0_rsc3_r1_2
# DETECTOR rec[-154] rec[-131] rec[-135] # readout_spans_c_z_3_rsc2
# DETECTOR rec[-150] rec[-137] rec[-130] rec[-133] rec[-136] # readout_spans_c_z_1_rsc2
# DETECTOR rec[-153] rec[-134] rec[-136] # readout_spans_c_z_2_rsc2
# DETECTOR rec[-147] rec[-130] rec[-138] rec[-132] rec[-131] # readout_spans_c_z_0_rsc2
# DETECTOR rec[-33] rec[-11] rec[-18] # readout_spans_c_z_2_rsc1
# DETECTOR rec[-27] rec[-16] rec[-12] # readout_spans_c_z_3_rsc1
# DETECTOR rec[-30] rec[-13] rec[-14] rec[-15] rec[-18] # readout_spans_c_z_1_rsc1
# DETECTOR rec[-31] rec[-14] rec[-10] rec[-17] rec[-12] # readout_spans_c_z_0_rsc1
# DETECTOR rec[-20] rec[-9] rec[-2] rec[-8] rec[-5] # readout_spans_c_z_1_rsc3
# DETECTOR rec[-26] rec[-6] rec[-7] # readout_spans_c_z_3_rsc3
# DETECTOR rec[-19] rec[-3] rec[-4] rec[-2] rec[-7] # readout_spans_c_z_0_rsc3
# DETECTOR rec[-21] rec[-9] rec[-1] # readout_spans_c_z_2_rsc3
# OBSERVABLE_INCLUDE(0) rec[-138] rec[-134] rec[-132]
# OBSERVABLE_INCLUDE(1) rec[-209] rec[-204] rec[-203] rec[-201] rec[-198] rec[-194] rec[-192] rec[-190] rec[-67] rec[-17] rec[-11] rec[-10] rec[-4] rec[-3] rec[-1]
# 3

# %% [markdown]
# Now that we know how to build a Stim program with its detectors, noise, and observable instructions, we just have to wrap it into a function that builds it for a given physical-noise level and distance. We can then run simulations using sinter to evaluate the logical error rates.

# %%
import matplotlib.pyplot as plt
import numpy as np
import stim

def cnot_rsc_circuit(distance: int, physical_noise: float):
    code1 = RotatedSurfaceCode.from_distance(distance=distance, system_coordinate=(0, 0))
    code2 = RotatedSurfaceCode.from_distance(distance=distance, system_coordinate=(0, 1))
    code3 = RotatedSurfaceCode.from_distance(distance=distance, system_coordinate=(1, 0))

    program = QuantumProgram(name="RSC_Surgery_Example")

    aq = program.add_qubit(AllocCode(target_code=code1, code_varname="ancilla_patch", logical_qubits_varnames=["ancilla"]))
    cq = program.add_qubit(AllocCode(target_code=code2, code_varname="control_patch", logical_qubits_varnames=["control"]))
    tq = program.add_qubit(AllocCode(target_code=code3, code_varname="target_patch", logical_qubits_varnames=["target"]))

    program.add_operation(QProgOperation(name="init_1", length=1, targets=[aq], implementation=InitCode(targets=["ancilla_patch"], initial_state=PauliEigenState.Z_plus, tag="init_ancilla")))
    program.add_operation(QProgOperation(name="init_2", length=1, targets=[cq], implementation=InitCode(targets=["control_patch"], initial_state=PauliEigenState.Z_plus, tag="init_control")))
    program.add_operation(QProgOperation(name="init_3", length=1, targets=[tq], implementation=InitCode(targets=["target_patch"], initial_state=PauliEigenState.Z_plus, tag="init_target")))

    program.add_operation(QProgOperation(name="MZZ_ac", length=1, targets=[cq, aq], implementation=RSCSurgery(targets=["control", "ancilla"], product_to_measure=PauliString(string=(PauliChar.Z, PauliChar.Z)), tag="MZZ_ac")))
    program.add_operation(QProgOperation(name="MXX_ct", length=1, targets=[aq, tq], implementation=RSCSurgery(targets=["ancilla", "target"], product_to_measure=PauliString(string=(PauliChar.X, PauliChar.X)), tag="MXX_ct")))
    program.add_operation(QProgOperation(name="LZ_control", length=1, targets=[cq], implementation=ReadoutCode(targets=["control_patch"], tag="LZ_control")))
    program.add_operation(QProgOperation(name="LZ_ancilla", length=1, targets=[aq], implementation=ReadoutCode(targets=["ancilla_patch"], tag="LZ_ancilla")))
    program.add_operation(QProgOperation(name="LZ_target", length=1, targets=[tq], implementation=ReadoutCode(targets=["target_patch"], tag="LZ_target")))


    config = {
        "primitives": {
            "epic.core.qec_primitives.interfaces.ApplyGate": "epic.modules.qec_primitives.SimpleGateApplication",
            "epic.core.qec_primitives.interfaces.Readout": "epic.modules.qec_primitives.NaiveReadout",
            "epic.core.qec_primitives.interfaces.ExtractSyndrome": "epic.modules.qec_primitives.RSCSyndromeExtraction",
        },
        "objective_distance": distance,
    }

    compiler = QECCompiler(config)
    compiled_program = compiler.compile(program)

    noise_model = StimLikeNoiseModel.from_stim_like_probabilities(
        after_clifford_depolarization=physical_noise,
        after_reset_flip_probability=physical_noise,
        before_measure_flip_probability=physical_noise,
        before_round_data_depolarization=physical_noise,
    )

    stim_observables = [["readout_LZ_control_rotated_surface_lq_0"], ["rsc_surgery_MZZ_ac", "readout_LZ_ancilla_rotated_surface_lq_0", "readout_LZ_target_rotated_surface_lq_0"]]
    stim_program = compiled_program.to_stim_program(stim_observables, noise_model)

    stim_circuit = stim.Circuit(stim_program)
    return stim_circuit

# %%
from typing import List
import sinter
from matplotlib import pyplot as plt
import numpy as np

tasks = [
    sinter.Task(
        circuit=cnot_rsc_circuit(distance=d, physical_noise=noise),
        json_metadata={"d": d, "p": noise},
    )
    for d in [3, 5, 7]
    for noise in list(np.logspace(-4, -2, 10))
]

collected_stats: List[sinter.TaskStats] = sinter.collect(
    num_workers=4,
    tasks=tasks,
    decoders=["pymatching"],
    max_shots=1_000_000,
    max_errors=500,
)
fig, ax = plt.subplots(1, 1)
sinter.plot_error_rate(
    ax=ax,
    stats=collected_stats,
    x_func=lambda stats: stats.json_metadata["p"],
    group_func=lambda stats: stats.json_metadata["d"],
)
ax.set_ylim(1e-7, 1e-0)
ax.set_xlim(1e-4, 1e-1)
ax.loglog()
ax.set_title("CNOT Code Error Rates")
ax.set_xlabel("Physical Error Rate")
ax.set_ylabel("Logical Error Rate per Shot")
ax.grid(which="major")
ax.grid(which="minor")
ax.legend()
fig.set_dpi(120)
